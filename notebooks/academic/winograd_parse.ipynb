# %% [markdown]
# ## Extract Information from Winograd Schema XML
#
# This notebook will extract linguistic information from Winograd Schema XML files and generate when-then rules for the engine.
#
# This isn't a perfect process, but rather is intended to demonstrate how to read existing academic data sets into the engine and how to begin using those data sets to construct rules. For example, this information could be used to generate a set of "plausible choices" given a premise.
#
# Note - You'll need the "request" library installed in your environment:
# pip install requests

# %% [markdown]
# ## Grab the Winograd Schema XML

# %%
# importing element tree
import xml.etree.ElementTree as ET 
import requests
from os.path import exists

file_cache_location = "..\\..\\temp\\WSCollection.xml"
file_exists = exists(file_cache_location)

if file_exists == False:
    print("Downloading schema file")
    URL = "https://cs.nyu.edu/~davise/papers/WinogradSchemas/WSCollection.xml"
    response = requests.get(URL)
    with open(file_cache_location, "wb") as temp_file:
        temp_file.write(response.content)
else:
    print("Using cache")
# Out:
# Using cache

# %% [markdown]
# ## Parse the File

# %%
tree = ET.parse(file_cache_location) 

root = tree.getroot() 
num = 0

rules = []

for elem in root.findall('schema'):

    # num = num + 1
    # if (num < 30 or num > 34): continue

    premise = str.strip(elem.find("text/txt1").text)
    pron = str.strip(elem.find("text/pron").text)
    focus = str.strip(elem.find("text/txt2").text)

    premise = premise.lower()
    premise = str.replace(premise, " because", "")
    premise = str.replace(premise, ", but", "")
    

    focus = str.replace(focus, ".","")

    print("Premise:", premise)
    print("Focus:", pron, focus)

    quote1 = elem.find("quote/quote1")
    quote1 = str.strip(quote1.text) if quote1 else ""
    qpron = str.strip(elem.find("quote/pron").text)
    quote2 = elem.find("quote/quote2")
    quote2 = str.strip(quote2.text) if quote2 else ""
    print("Referent:",quote1,qpron,quote2)

    correct_answer = str.strip(elem.find("correctAnswer").text.lower())
    correct_answer = str.replace(correct_answer,".", "")
    correct_answer_idx = ord(correct_answer) - ord("a") + 1
    # print(correct_answer, correct_answer_idx)

    answers = elem.findall("answers/answer")
    answer = answers[correct_answer_idx-1]
    answer_text = str.strip(answer.text)
    print("Answer:", answer_text)

    answer_text = answer_text.lower()
    when_clause = premise.replace(answer_text, "?x")
    then_clause = "?x " + focus

    when_clause = str.strip(when_clause)
    then_clause = str.strip(then_clause)

    print("#when:", when_clause)
    print("#then:", then_clause)

    rule = {"#when": when_clause, "#then": then_clause}
    rules.append(rule)

    print("")
# Out:
# Premise: the city councilmen refused the demonstrators a permit
# Focus: they feared violence
# Referent:  they
# Answer: The city councilmen
# #when: ?x refused the demonstrators a permit
# #then: ?x feared violence
#
# Premise: the city councilmen refused the demonstrators a permit
# Focus: they advocated violence
# Referent:  they
# Answer: The demonstrators
# #when: the city councilmen refused ?x a permit
# #then: ?x advocated violence
#
# Premise: the trophy doesn't fit into the brown suitcase
# Focus: it is too large
# Referent:  it
# Answer: the trophy
# #when: ?x doesn't fit into the brown suitcase
# #then: ?x is too large
#
# Premise: the trophy doesn't fit into the brown suitcase
# Focus: it is too small
# Referent:  it
# Answer: the suitcase
# #when: the trophy doesn't fit into the brown suitcase
# #then: ?x is too small
#
# Premise: joan made sure to thank susan for all the help
# Focus: she had recieved
# Referent:  she
# Answer: Joan
# #when: ?x made sure to thank susan for all the help
# #then: ?x had recieved
#
# Premise: joan made sure to thank susan for all the help
# Focus: she had given
# Referent:  she
# Answer: Susan
# #when: joan made sure to thank ?x for all the help
# #then: ?x had given
#
# Premise: paul tried to call george on the phone
# Focus: he wasn't successful
# Referent:  he
# Answer: Paul
# #when: ?x tried to call george on the phone
# #then: ?x wasn't successful
#
# Premise: paul tried to call george on the phone
# Focus: he wasn't available
# Referent:  he
# Answer: George
# #when: paul tried to call ?x on the phone
# #then: ?x wasn't available
#
# Premise: the lawyer asked the witness a question
# Focus: he was reluctant to repeat it
# Referent:  he
# Answer: the lawyer
# #when: ?x asked the witness a question
# #then: ?x was reluctant to repeat it
#
# Premise: the lawyer asked the witness a question
# Focus: he was reluctant to answer it
# Referent:  he
# Answer: the witness
# #when: the lawyer asked ?x a question
# #then: ?x was reluctant to answer it
#
# Premise: the delivery truck zoomed by the school bus
# Focus: it was going so fast
# Referent:  it
# Answer: the delivery truck
# #when: ?x zoomed by the school bus
# #then: ?x was going so fast
#
# Premise: the delivery truck zoomed by the school bus
# Focus: it was going so slow
# Referent:  it
# Answer: the school bus
# #when: the delivery truck zoomed by ?x
# #then: ?x was going so slow
#
# Premise: frank felt vindicated when his longtime rival bill revealed that
# Focus: he was the winner of the competition
# Referent:  he
# Answer: Frank
# #when: ?x felt vindicated when his longtime rival bill revealed that
# #then: ?x was the winner of the competition
#
# Premise: frank felt crushed when his longtime rival bill revealed that
# Focus: he was the winner of the competition
# Referent:  he
# Answer: Bill
# #when: frank felt crushed when his longtime rival ?x revealed that
# #then: ?x was the winner of the competition
#
# Premise: the man couldn't lift his son
# Focus: he was so weak
# Referent:  he
# Answer: The man
# #when: ?x couldn't lift his son
# #then: ?x was so weak
#
# Premise: the man couldn't lift his son
# Focus: he was so heavy
# Referent:  he
# Answer: The son
# #when: the man couldn't lift his son
# #then: ?x was so heavy
#
# Premise: the large ball crashed right through the table
# Focus: it was made of steel
# Referent:  it
# Answer: The large ball
# #when: ?x crashed right through the table
# #then: ?x was made of steel
#
# Premise: the large ball crashed right through the table
# Focus: it was made of styrofoam
# Referent:  it
# Answer: The table
# #when: the large ball crashed right through ?x
# #then: ?x was made of styrofoam
#
# Premise: john couldn't see the stage with billy in front of him
# Focus: he is so short
# Referent:  he
# Answer: John
# #when: ?x couldn't see the stage with billy in front of him
# #then: ?x is so short
#
# Premise: john couldn't see the stage with billy in front of him
# Focus: he is so tall
# Referent:  he
# Answer: Billy
# #when: john couldn't see the stage with ?x in front of him
# #then: ?x is so tall
#
# Premise: tom threw his schoolbag down to ray after
# Focus: he reached the top of the stairs
# Referent:  he
# Answer: Tom
# #when: ?x threw his schoolbag down to ray after
# #then: ?x reached the top of the stairs
#
# Premise: tom threw his schoolbag down to ray after
# Focus: he reached the bottom of the stairs
# Referent:  he
# Answer: Ray
# #when: tom threw his schoolbag down to ?x after
# #then: ?x reached the bottom of the stairs
#
# Premise: although they ran at about the same speed, sue beat sally
# Focus: she had such a good start
# Referent:  she
# Answer: Sue
# #when: although they ran at about the same speed, ?x beat sally
# #then: ?x had such a good start
#
# Premise: although they ran at about the same speed, sue beat sally
# Focus: she had such a bad start
# Referent:  she
# Answer: Sally
# #when: although they ran at about the same speed, sue beat ?x
# #then: ?x had such a bad start
#
# Premise: the sculpture rolled off the shelf
# Focus: it wasn't anchored
# Referent:  it
# Answer: The sculpture
# #when: ?x rolled off the shelf
# #then: ?x wasn't anchored
#
# Premise: the sculpture rolled off the shelf
# Focus: it wasn't level
# Referent:  it
# Answer: The shelf
# #when: the sculpture rolled off ?x
# #then: ?x wasn't level
#
# Premise: sam's drawing was hung just above tina's and
# Focus: it did look much better with another one below it
# Referent:  it
# Answer: Sam's drawing
# #when: ?x was hung just above tina's and
# #then: ?x did look much better with another one below it
#
# Premise: sam's drawing was hung just above tina's and
# Focus: it did look much better with another one above it
# Referent:  it
# Answer: Tina's drawing
# #when: sam's drawing was hung just above tina's and
# #then: ?x did look much better with another one above it
#
# Premise: anna did a lot better than her good friend lucy on the test
# Focus: she had studied so hard
# Referent:  she
# Answer: Anna
# #when: ?x did a lot better than her good friend lucy on the test
# #then: ?x had studied so hard
#
# Premise: anna did a lot worse than her good friend lucy on the test
# Focus: she had studied so hard
# Referent:  she
# Answer: Lucy
# #when: anna did a lot worse than her good friend ?x on the test
# #then: ?x had studied so hard
#
# Premise: the firemen arrived after the police
# Focus: they were coming from so far away
# Referent:  they
# Answer: The firemen
# #when: ?x arrived after the police
# #then: ?x were coming from so far away
#
# Premise: the firemen arrived before the police
# Focus: they were coming from so far away
# Referent:  they
# Answer: The police
# #when: the firemen arrived before ?x
# #then: ?x were coming from so far away
#
# Premise: frank was upset with tom the toaster
# Focus: he had bought from him didn't work
# Referent:  he
# Answer: Frank
# #when: ?x was upset with tom the toaster
# #then: ?x had bought from him didn't work
#
# Premise: frank was upset with tom the toaster
# Focus: he had sold him didn't work
# Referent:  he
# Answer: Tom
# #when: frank was upset with ?x the toaster
# #then: ?x had sold him didn't work
#
# Premise: jim yelled at kevin
# Focus: he was so upset
# Referent:  he
# Answer: Jim
# #when: ?x yelled at kevin
# #then: ?x was so upset
#
# Premise: jim comforted kevin
# Focus: he was so upset
# Referent:  he
# Answer: Kevin
# #when: jim comforted ?x
# #then: ?x was so upset
#
# Premise: the sack of potatoes had been placed above
# the bag of flour, so
# Focus: it had to be moved first
# Referent:  it
# Answer: The sack of potatoes
# #when: ?x had been placed above
# the bag of flour, so
# #then: ?x had to be moved first
#
# Premise: the sack of potatoes had been placed below
# the bag of flour, so
# Focus: it had to be moved first
# Referent:  it
# Answer: The bag of flour
# #when: the sack of potatoes had been placed below
# ?x, so
# #then: ?x had to be moved first
#
# Premise: pete envies martin although
# Focus: he is very successful
# Referent:  he
# Answer: Pete
# #when: ?x envies martin although
# #then: ?x is very successful
#
# Premise: pete envies martin
# Focus: he is very successful
# Referent:  he
# Answer: Martin
# #when: pete envies ?x
# #then: ?x is very successful
#
# Premise: the older students were bullying the younger ones, so we punished
# Focus: them
# Referent:  them
# Answer: The older students
# #when: ?x were bullying the younger ones, so we punished
# #then: ?x
#
# Premise: the older students were bullying the younger ones, so we rescued
# Focus: them
# Referent:  them
# Answer: The younger students
# #when: the older students were bullying the younger ones, so we rescued
# #then: ?x
#
# Premise: i poured water from the bottle into the cup until
# Focus: it was empty
# Referent:  it
# Answer: the bottle
# #when: i poured water from ?x into the cup until
# #then: ?x was empty
#
# Premise: i poured water from the bottle into the cup until
# Focus: it was full
# Referent:  it
# Answer: the cup
# #when: i poured water from the bottle into ?x until
# #then: ?x was full
#
# Premise: susan knows all about ann's personal problems
# Focus: she is nosy
# Referent:  she
# Answer: Susan
# #when: ?x knows all about ann's personal problems
# #then: ?x is nosy
#
# Premise: susan knows all about ann's personal problems
# Focus: she is indiscreet
# Referent:  she
# Answer: Ann
# #when: susan knows all about ?x's personal problems
# #then: ?x is indiscreet
#
# Premise: sid explained his theory to mark but
# Focus: he couldn't convince him
# Referent:  he
# Answer: Sid
# #when: ?x explained his theory to mark but
# #then: ?x couldn't convince him
#
# Premise: sid explained his theory to mark but
# Focus: he couldn't understand him
# Referent:  he
# Answer: Mark
# #when: sid explained his theory to ?x but
# #then: ?x couldn't understand him
#
# Premise: susan knew that ann's son had been in a car accident, so
# Focus: she told her about it
# Referent:  she
# Answer: Susan
# #when: ?x knew that ann's son had been in a car accident, so
# #then: ?x told her about it
#
# Premise: susan knew that ann's son had been in a car accident,
# Focus: she told her about it
# Referent:  she
# Answer: Ann
# #when: susan knew that ?x's son had been in a car accident,
# #then: ?x told her about it
#
# Premise: joe's uncle can still beat him at tennis, even though
# Focus: he is 30 years younger
# Referent:  he
# Answer: Joe
# #when: ?x's uncle can still beat him at tennis, even though
# #then: ?x is 30 years younger
#
# Premise: joe's uncle can still beat him at tennis, even though
# Focus: he is 30 years older
# Referent:  he
# Answer: Joe's uncle
# #when: ?x can still beat him at tennis, even though
# #then: ?x is 30 years older
#
# Premise: the painting in mark's living room shows an oak tree.
# Focus: It is to the right of the bookcase
# Referent:  it
# Answer: The painting
# #when: ?x in mark's living room shows an oak tree.
# #then: ?x is to the right of the bookcase
#
# Premise: the painting in mark's living room shows an oak tree.
# Focus: It is to the right of a house
# Referent:  it
# Answer: The oak tree
# #when: the painting in mark's living room shows an oak tree.
# #then: ?x is to the right of a house
#
# Premise: there is a gap in the wall. you can see the garden through
# Focus: it
# Referent:  it
# Answer: The gap
# #when: there is a gap in the wall. you can see the garden through
# #then: ?x
#
# Premise: there is a gap in the wall. you can see the garden behind
# Focus: it
# Referent:  it
# Answer: The wall
# #when: there is a gap in ?x. you can see the garden behind
# #then: ?x
#
# Premise: the drain is clogged with hair.
# Focus: It has to be cleaned
# Referent:  It
# Answer: The drain
# #when: ?x is clogged with hair.
# #then: ?x has to be cleaned
#
# Premise: the drain is clogged with hair.
# Focus: It has to be removed
# Referent:  It
# Answer: The hair
# #when: the drain is clogged with hair.
# #then: ?x has to be removed
#
# Premise: my meeting started at 4:00 and i needed to catch the train at 4:30,
# so there wasn't much time. luckily,
# Focus: it was short, so it worked out
# Referent:  it
# Answer: The meeting
# #when: my meeting started at 4:00 and i needed to catch the train at 4:30,
# so there wasn't much time. luckily,
# #then: ?x was short, so it worked out
#
# Premise: my meeting started at 4:00 and i needed to catch the train at 4:30,
# so there wasn't much time. luckily,
# Focus: it was delayed, so it worked out
# Referent:  it
# Answer: The train
# #when: my meeting started at 4:00 and i needed to catch ?x at 4:30,
# so there wasn't much time. luckily,
# #then: ?x was delayed, so it worked out
#
# Premise: there is a pillar between me and the stage, and i can't see around
# Focus: it
# Referent:  it
# Answer: The pillar
# #when: there is a pillar between me and the stage, and i can't see around
# #then: ?x
#
# Premise: there is a pillar between me and the stage, and i can't see
# Focus: it
# Referent:  it
# Answer: The stage
# #when: there is a pillar between me and ?x, and i can't see
# #then: ?x
#
# Premise: they broadcast an announcement a subway came into the
# station and i couldn't hear
# Focus: it
# Referent:  it
# Answer: The announcement
# #when: they broadcast an announcement a subway came into the
# station and i couldn't hear
# #then: ?x
#
# Premise: they broadcast an announcement a subway came into the
# station and i couldn't hear over
# Focus: it
# Referent:  it
# Answer: The subway
# #when: they broadcast an announcement a subway came into the
# station and i couldn't hear over
# #then: ?x
#
# Premise: in the middle of the outdoor concert, the rain started falling
# Focus: it continued until 10
# Referent:  it
# Answer: The concert
# #when: in the middle of the outdoor concert, the rain started falling
# #then: ?x continued until 10
#
# Premise: in the middle of the outdoor concert, the rain started falling, and
# Focus: it continued until 10
# Referent:  it
# Answer: The rain
# #when: in the middle of the outdoor concert, ?x started falling, and
# #then: ?x continued until 10
#
# Premise: i used an old rag to clean the knife, and then i put
# Focus: it in the trash
# Referent:  it
# Answer: The rag
# #when: i used an old rag to clean the knife, and then i put
# #then: ?x in the trash
#
# Premise: i used an old rag to clean the knife, and then i put
# Focus: it in the drawer
# Referent:  it
# Answer: The knife
# #when: i used an old rag to clean ?x, and then i put
# #then: ?x in the drawer
#
# Premise: ann asked mary what time the library closes,
# Focus: she had forgotten
# Referent:  she
# Answer: Ann
# #when: ?x asked mary what time the library closes,
# #then: ?x had forgotten
#
# Premise: ann asked mary what time the library closes
# Focus: she had forgotten
# Referent:  she
# Answer: Mary
# #when: ann asked ?x what time the library closes
# #then: ?x had forgotten
#
# Premise: i took the water bottle out of the backpack so that
# Focus: it would be handy
# Referent:  it
# Answer: The water bottle
# #when: i took ?x out of the backpack so that
# #then: ?x would be handy
#
# Premise: i took the water bottle out of the backpack so that
# Focus: it would be lighter
# Referent:  it
# Answer: The backpack
# #when: i took the water bottle out of ?x so that
# #then: ?x would be lighter
#
# Premise: i couldn't put the pot on the shelf
# Focus: it was too tall
# Referent:  it
# Answer: The pot
# #when: i couldn't put ?x on the shelf
# #then: ?x was too tall
#
# Premise: i couldn't put the pot on the shelf
# Focus: it was too high
# Referent:  it
# Answer: The shelf
# #when: i couldn't put the pot on ?x
# #then: ?x was too high
#
# Premise: i'm sure that my map will show this building;
# Focus: it is very good
# Referent:  it
# Answer: The map
# #when: i'm sure that my map will show this building;
# #then: ?x is very good
#
# Premise: i'm sure that my map will show this building;
# Focus: it is very famous
# Referent:  it
# Answer: The building
# #when: i'm sure that my map will show this building;
# #then: ?x is very famous
#
# Premise: bob paid for charlie's college education.
# Focus: He is very generous
# Referent:  He
# Answer: Bob
# #when: ?x paid for charlie's college education.
# #then: ?x is very generous
#
# Premise: bob paid for charlie's college education.
# Focus: He is very grateful
# Referent:  He
# Answer: Charlie
# #when: bob paid for ?x's college education.
# #then: ?x is very grateful
#
# Premise: bob paid for charlie's college education now charlie acts as though
# it never happened.
# Focus: He is very hurt
# Referent:  He
# Answer: Bob
# #when: ?x paid for charlie's college education now charlie acts as though
# it never happened.
# #then: ?x is very hurt
#
# Premise: bob paid for charlie's college education now charlie acts as though
# it never happened.
# Focus: He is very ungrateful
# Referent:  He
# Answer: Charlie
# #when: bob paid for ?x's college education now ?x acts as though
# it never happened.
# #then: ?x is very ungrateful
#
# Premise: bob was playing cards with adam and was way ahead. if adam hadn't had a
# sudden run of good luck,
# Focus: he would have won
# Referent:  he
# Answer: Bob
# #when: ?x was playing cards with adam and was way ahead. if adam hadn't had a
# sudden run of good luck,
# #then: ?x would have won
#
# Premise: bob was playing cards with adam and was way ahead. if adam hadn't had a
# sudden run of good luck,
# Focus: he would have lost
# Referent:  he
# Answer: Adam
# #when: bob was playing cards with ?x and was way ahead. if ?x hadn't had a
# sudden run of good luck,
# #then: ?x would have lost
#
# Premise: adam can't leave work here until bob arrives to replace him. if bob had
# left home for work on time,
# Focus: he would be gone by this time
# Referent:  he
# Answer: Adam
# #when: ?x can't leave work here until bob arrives to replace him. if bob had
# left home for work on time,
# #then: ?x would be gone by this time
#
# Premise: adam can't leave work here until bob arrives to replace him. if bob had
# left home for work on time,
# Focus: he would be here by this time
# Referent:  he
# Answer: Bob
# #when: adam can't leave work here until ?x arrives to replace him. if ?x had
# left home for work on time,
# #then: ?x would be here by this time
#
# Premise: if the con artist has succeeded in fooling sam,
# Focus: he would have gotten a lot of money
# Referent:  he
# Answer: The con artist
# #when: if ?x has succeeded in fooling sam,
# #then: ?x would have gotten a lot of money
#
# Premise: if the con artist has succeeded in fooling sam,
# Focus: he would have lost a lot of money
# Referent:  he
# Answer: Sam
# #when: if the con artist has succeeded in fooling ?x,
# #then: ?x would have lost a lot of money
#
# Premise: it was a summer afternoon, and the dog was sitting in the middle of the
# lawn. after a while, it got up and moved to a spot under the tree,
# because
# Focus: it was hot
# Referent:  it
# Answer: The dog
# #when: it was a summer afternoon, and ?x was sitting in the middle of the
# lawn. after a while, it got up and moved to a spot under the tree,
# because
# #then: ?x was hot
#
# Premise: it was a summer afternoon, and the dog was sitting in the middle of the
# lawn. after a while, it got up and moved to a spot under the tree,
# because
# Focus: it was cooler
# Referent:  it
# Answer: The spot under the tree
# #when: it was a summer afternoon, and the dog was sitting in the middle of the
# lawn. after a while, it got up and moved to a spot under the tree,
# because
# #then: ?x was cooler
#
# Premise: the cat was lying by the mouse hole waiting for the mouse
# Focus: it was too impatient
# Referent:  it
# Answer: The cat
# #when: ?x was lying by the mouse hole waiting for the mouse
# #then: ?x was too impatient
#
# Premise: the cat was lying by the mouse hole waiting for the mouse
# Focus: it was too cautious
# Referent:  it
# Answer: The mouse
# #when: the cat was lying by ?x hole waiting for ?x
# #then: ?x was too cautious
#
# Premise: anne gave birth to a daughter last month.
# Focus: She is a very charming woman
# Referent:  She
# Answer: Anne
# #when: ?x gave birth to a daughter last month.
# #then: ?x is a very charming woman
#
# Premise: anne gave birth to a daughter last month.
# Focus: She is a very charming baby
# Referent:  She
# Answer: Anne's daughter
# #when: anne gave birth to a daughter last month.
# #then: ?x is a very charming baby
#
# Premise: alice tried frantically to stop her daughter from chatting at
# the party, leaving us to wonder why
# Focus: she was behaving so strangely
# Referent:  she
# Answer: Alice
# #when: ?x tried frantically to stop her daughter from chatting at
# the party, leaving us to wonder why
# #then: ?x was behaving so strangely
#
# Premise: alice tried frantically to stop her daughter from barking at
# the party, leaving us to wonder why
# Focus: she was behaving so strangely
# Referent:  she
# Answer: Alice's daughter
# #when: alice tried frantically to stop her daughter from barking at
# the party, leaving us to wonder why
# #then: ?x was behaving so strangely
#
# Premise: i saw jim yelling at some guy in a military uniform with a huge red
# beard. i don't know why
# Focus: he was, but he looked very unhappy
# Referent:  he
# Answer: Jim
# #when: i saw ?x yelling at some guy in a military uniform with a huge red
# beard. i don't know why
# #then: ?x was, but he looked very unhappy
#
# Premise: i saw jim yelling at some guy in a military uniform with a huge red
# beard. i don't know who
# Focus: he was, but he looked very unhappy
# Referent:  he
# Answer: the guy in uniform
# #when: i saw jim yelling at some guy in a military uniform with a huge red
# beard. i don't know who
# #then: ?x was, but he looked very unhappy
#
# Premise: the fish ate the worm.
# Focus: It was hungry
# Referent:  It
# Answer: The fish
# #when: ?x ate the worm.
# #then: ?x was hungry
#
# Premise: the fish ate the worm.
# Focus: It was tasty
# Referent:  It
# Answer: The worm
# #when: the fish ate ?x.
# #then: ?x was tasty
#
# Premise: i was trying to open the lock with the key someone had filled the
# keyhole with chewing gum, and i couldn't get
# Focus: it in
# Referent:  it
# Answer: The key
# #when: i was trying to open the lock with ?x someone had filled the
# keyhole with chewing gum, and i couldn't get
# #then: ?x in
#
# Premise: i was trying to open the lock with the key someone had filled the
# keyhole with chewing gum, and i couldn't get
# Focus: it out
# Referent:  it
# Answer: The chewing gum
# #when: i was trying to open the lock with the key someone had filled the
# keyhole with chewing gum, and i couldn't get
# #then: ?x out
#
# Premise: the dog chased the cat, which ran up a tree.
# Focus: It waited at the bottom
# Referent:  It
# Answer: The dog
# #when: ?x chased the cat, which ran up a tree.
# #then: ?x waited at the bottom
#
# Premise: the dog chased the cat, which ran up a tree.
# Focus: It waited at the top
# Referent:  It
# Answer: The cat
# #when: the dog chased ?x, which ran up a tree.
# #then: ?x waited at the top
#
# Premise: in the storm, the tree fell down and crashed through the roof of my
# house. now, i have to get
# Focus: it removed
# Referent:  it
# Answer: The tree
# #when: in the storm, ?x fell down and crashed through the roof of my
# house. now, i have to get
# #then: ?x removed
#
# Premise: in the storm, the tree fell down and crashed through the roof of my
# house. now, i have to get
# Focus: it repaired
# Referent:  it
# Answer: The roof
# #when: in the storm, the tree fell down and crashed through ?x of my
# house. now, i have to get
# #then: ?x repaired
#
# Premise: the customer walked into the bank and stabbed one of the tellers.
# Focus: He was immediately taken to the police station
# Referent:  He
# Answer: The customer
# #when: ?x walked into the bank and stabbed one of the tellers.
# #then: ?x was immediately taken to the police station
#
# Premise: the customer walked into the bank and stabbed one of the tellers.
# Focus: He was immediately taken to the hospital
# Referent:  He
# Answer: The teller
# #when: the customer walked into the bank and stabbed one of ?xs.
# #then: ?x was immediately taken to the hospital
#
# Premise: john was doing research in the library when he heard a man humming and
# whistling.
# Focus: He was very annoyed
# Referent:  He
# Answer: John
# #when: ?x was doing research in the library when he heard a man humming and
# whistling.
# #then: ?x was very annoyed
#
# Premise: john was doing research in the library when he heard a man humming and
# whistling.
# Focus: He was very annoying
# Referent:  He
# Answer: The man
# #when: john was doing research in the library when he heard a man humming and
# whistling.
# #then: ?x was very annoying
#
# Premise: john was jogging through the park when he saw a man juggling watermelons.
# Focus: He was very impressed
# Referent:  He
# Answer: John
# #when: ?x was jogging through the park when he saw a man juggling watermelons.
# #then: ?x was very impressed
#
# Premise: john was jogging through the park when he saw a man juggling watermelons.
# Focus: He was very impressive
# Referent:  He
# Answer: The juggler
# #when: john was jogging through the park when he saw a man juggling watermelons.
# #then: ?x was very impressive
#
# Premise: bob collapsed on the sidewalk. soon he saw carl coming to help.
# Focus: He was very ill
# Referent:  He
# Answer: Bob
# #when: ?x collapsed on the sidewalk. soon he saw carl coming to help.
# #then: ?x was very ill
#
# Premise: bob collapsed on the sidewalk. soon he saw carl coming to help.
# Focus: He was very concerned
# Referent:  He
# Answer: Carl
# #when: bob collapsed on the sidewalk. soon he saw ?x coming to help.
# #then: ?x was very concerned
#
# Premise: sam and amy are passionately in love amy's parents are unhappy
# about it,
# Focus: they are fifteen
# Referent:  they
# Answer: Sam and Amy
# #when: ?x are passionately in love amy's parents are unhappy
# about it,
# #then: ?x are fifteen
#
# Premise: sam and amy are passionately in love amy's parents are unhappy
# about it,
# Focus: they are snobs
# Referent:  they
# Answer: Amy's parents
# #when: sam and amy are passionately in love ?x are unhappy
# about it,
# #then: ?x are snobs
#
# Premise: mark told pete many lies about himself, which pete included in his book.
# Focus: He should have been more  truthful
# Referent:  He
# Answer: Mark
# #when: ?x told pete many lies about himself, which pete included in his book.
# #then: ?x should have been more  truthful
#
# Premise: mark told pete many lies about himself, which pete included in his book.
# Focus: He should have been more  skeptical
# Referent:  He
# Answer: Pete
# #when: mark told ?x many lies about himself, which ?x included in his book.
# #then: ?x should have been more  skeptical
#
# Premise: joe has sold his house and bought a new one a few miles away. he will
# be moving out of
# Focus: it on Thursday
# Referent:  it
# Answer: The old house
# #when: joe has sold his house and bought a new one a few miles away. he will
# be moving out of
# #then: ?x on Thursday
#
# Premise: joe has sold his house and bought a new one a few miles away. he will
# be moving into
# Focus: it on Thursday
# Referent:  it
# Answer: The new house
# #when: joe has sold his house and bought a new one a few miles away. he will
# be moving into
# #then: ?x on Thursday
#
# Premise: many people start to read paul's books and can't put them down.
# Focus: They are gripped because Paul writes so well
# Referent:  They
# Answer: People
# #when: many ?x start to read paul's books and can't put them down.
# #then: ?x are gripped because Paul writes so well
#
# Premise: many people start to read paul's books and can't put them down.
# Focus: They are popular because Paul writes so well
# Referent:  They
# Answer: Paul's books
# #when: many people start to read ?x and can't put them down.
# #then: ?x are popular because Paul writes so well
#
# Premise: mary took out her flute and played one of her favorite pieces. she
# has had
# Focus: it since she was a child
# Referent:  it
# Answer: The flute
# #when: mary took out her flute and played one of her favorite pieces. she
# has had
# #then: ?x since she was a child
#
# Premise: mary took out her flute and played one of her favorite pieces. she
# has loved
# Focus: it since she was a child
# Referent:  it
# Answer: The piece
# #when: mary took out her flute and played one of her favorite pieces. she
# has loved
# #then: ?x since she was a child
#
# Premise: sam pulled up a chair to the piano
# Focus: it was broken, so he had to stand instead
# Referent:  it
# Answer: The chair
# #when: sam pulled up a chair to the piano
# #then: ?x was broken, so he had to stand instead
#
# Premise: sam pulled up a chair to the piano
# Focus: it was broken, so he had to sing instead
# Referent:  it
# Answer: The piano
# #when: sam pulled up a chair to ?x
# #then: ?x was broken, so he had to sing instead
#
# Premise: since it was raining, i carried the newspaper in my backpack to keep
# Focus: it dry
# Referent:  it
# Answer: The newspaper
# #when: since it was raining, i carried ?x in my backpack to keep
# #then: ?x dry
#
# Premise: since it was raining, i carried the newspaper over my backpack to keep
# Focus: it dry
# Referent:  it
# Answer: The backpack
# #when: since it was raining, i carried the newspaper over my backpack to keep
# #then: ?x dry
#
# Premise: sara borrowed the book from the library she needs it for an
# article she is working on. she reads
# Focus: it when she gets home from work
# Referent:  it
# Answer: The book
# #when: sara borrowed ?x from the library she needs it for an
# article she is working on. she reads
# #then: ?x when she gets home from work
#
# Premise: sara borrowed the book from the library she needs it for an
# article she is working on. she writes
# Focus: it when she gets home from work
# Referent:  it
# Answer: The article
# #when: sara borrowed the book from the library she needs it for an
# article she is working on. she writes
# #then: ?x when she gets home from work
#
# Premise: this morning, joey built a sand castle on the beach, and put a toy
# flag in the highest tower this afternoon the tide
# knocked
# Focus: it down
# Referent:  it
# Answer: The sand castle
# #when: this morning, joey built a sand castle on the beach, and put a toy
# flag in the highest tower this afternoon the tide
# knocked
# #then: ?x down
#
# Premise: this morning, joey built a sand castle on the beach, and put a toy
# flag in the highest tower this afternoon the wind
# knocked
# Focus: it down
# Referent:  it
# Answer: The flag
# #when: this morning, joey built a sand castle on the beach, and put a toy
# flag in the highest tower this afternoon the wind
# knocked
# #then: ?x down
#
# Premise: jane knocked on susan's door there was no answer.
# Focus: She was disappointed
# Referent:  She
# Answer: Jane
# #when: ?x knocked on susan's door there was no answer.
# #then: ?x was disappointed
#
# Premise: jane knocked on susan's door there was no answer.
# Focus: She was out
# Referent:  She
# Answer: Susan
# #when: jane knocked on ?x's door there was no answer.
# #then: ?x was out
#
# Premise: jane knocked on the door, and susan answered it.
# Focus: She invited her to come out
# Referent:  She
# Answer: Jane
# #when: ?x knocked on the door, and susan answered it.
# #then: ?x invited her to come out
#
# Premise: jane knocked on the door, and susan answered it.
# Focus: She invited her to come in
# Referent:  She
# Answer: Susan
# #when: jane knocked on the door, and ?x answered it.
# #then: ?x invited her to come in
#
# Premise: sam took french classes from adam,
# Focus: he was eager to speak it fluently
# Referent:  he
# Answer: Sam
# #when: ?x took french classes from adam,
# #then: ?x was eager to speak it fluently
#
# Premise: sam took french classes from adam,
# Focus: he was known to speak it fluently
# Referent:  he
# Answer: Adam
# #when: sam took french classes from ?x,
# #then: ?x was known to speak it fluently
#
# Premise: the path to the lake was blocked, so we couldn't use
# Focus: it
# Referent:  it
# Answer: The path
# #when: ?x to the lake was blocked, so we couldn't use
# #then: ?x
#
# Premise: the path to the lake was blocked, so we couldn't reach
# Focus: it
# Referent:  it
# Answer: The lake
# #when: the path to ?x was blocked, so we couldn't reach
# #then: ?x
#
# Premise: the sun was covered by a thick cloud all morning luckily, by the time
# the picnic started,
# Focus: it was out
# Referent:  it
# Answer: The sun
# #when: ?x was covered by a thick cloud all morning luckily, by the time
# the picnic started,
# #then: ?x was out
#
# Premise: the sun was covered by a thick cloud all morning luckily, by the time
# the picnic started,
# Focus: it was gone
# Referent:  it
# Answer: The cloud
# #when: the sun was covered by a thick cloud all morning luckily, by the time
# the picnic started,
# #then: ?x was gone
#
# Premise: we went to the lake, a shark had been seen at the ocean beach, so
# Focus: it was a safer place to swim
# Referent:  it
# Answer: The lake
# #when: we went to ?x, a shark had been seen at the ocean beach, so
# #then: ?x was a safer place to swim
#
# Premise: we went to the lake, a shark had been seen at the ocean beach, so
# Focus: it was a dangerous place to swim
# Referent:  it
# Answer: The ocean beach
# #when: we went to the lake, a shark had been seen at ?x, so
# #then: ?x was a dangerous place to swim
#
# Premise: sam tried to paint a picture of shepherds with sheep
# Focus: they ended up looking more like golfers
# Referent:  they
# Answer: The shepherds
# #when: sam tried to paint a picture of shepherds with sheep
# #then: ?x ended up looking more like golfers
#
# Premise: sam tried to paint a picture of shepherds with sheep
# Focus: they ended up looking more like dogs
# Referent:  they
# Answer: The sheep
# #when: sam tried to paint a picture of shepherds with sheep
# #then: ?x ended up looking more like dogs
#
# Premise: mary tucked her daughter anne into bed, so that
# Focus: she could work
# Referent:  she
# Answer: Mary
# #when: ?x tucked her daughter anne into bed, so that
# #then: ?x could work
#
# Premise: mary tucked her daughter anne into bed, so that
# Focus: she could sleep
# Referent:  she
# Answer: Mary's daughter
# #when: mary tucked her daughter anne into bed, so that
# #then: ?x could sleep
#
# Premise: fred and alice had very warm down coats
# Focus: they were not prepared for the cold in Alaska
# Referent:  they
# Answer: Fred and Alice
# #when: ?x had very warm down coats
# #then: ?x were not prepared for the cold in Alaska
#
# Premise: fred and alice had very warm down coats
# Focus: they were not enough for the cold in Alaska
# Referent:  they
# Answer: coats
# #when: fred and alice had very warm down ?x
# #then: ?x were not enough for the cold in Alaska
#
# Premise: thomson visited cooper's grave in 1765. at that date
# Focus: he had been travelling for five years
# Referent:  he
# Answer: Thomson
# #when: ?x visited cooper's grave in 1765. at that date
# #then: ?x had been travelling for five years
#
# Premise: thomson visited cooper's grave in 1765. at that date
# Focus: he had been dead for five years
# Referent:  he
# Answer: Cooper
# #when: thomson visited ?x's grave in 1765. at that date
# #then: ?x had been dead for five years
#
# Premise: jackson was greatly influenced by arnold, though
# Focus: he lived two centuries later
# Referent:  he
# Answer: Jackson
# #when: ?x was greatly influenced by arnold, though
# #then: ?x lived two centuries later
#
# Premise: jackson was greatly influenced by arnold, though
# Focus: he lived two centuries earlier
# Referent:  he
# Answer: Arnold
# #when: jackson was greatly influenced by ?x, though
# #then: ?x lived two centuries earlier
#
# Premise: i can't cut that tree down with that axe;
# Focus: it is too thick
# Referent:  it
# Answer: The tree
# #when: i can't cut that tree down with that axe;
# #then: ?x is too thick
#
# Premise: i can't cut that tree down with that axe;
# Focus: it is too small
# Referent:  it
# Answer: The axe
# #when: i can't cut that tree down with that axe;
# #then: ?x is too small
#
# Premise: the foxes are getting in at night and attacking the chickens. i shall have
# to kill
# Focus: them
# Referent:  them
# Answer: The foxes
# #when: ?x are getting in at night and attacking the chickens. i shall have
# to kill
# #then: ?x
#
# Premise: the foxes are getting in at night and attacking the chickens. i shall have
# to guard
# Focus: them
# Referent:  them
# Answer: The chickens
# #when: the foxes are getting in at night and attacking ?x. i shall have
# to guard
# #then: ?x
#
# Premise: the foxes are getting in at night and attacking the chickens.
# Focus: They have gotten very bold
# Referent:  They
# Answer: The foxes
# #when: ?x are getting in at night and attacking the chickens.
# #then: ?x have gotten very bold
#
# Premise: the foxes are getting in at night and attacking the chickens.
# Focus: They have gotten very nervous
# Referent:  They
# Answer: The chickens
# #when: the foxes are getting in at night and attacking ?x.
# #then: ?x have gotten very nervous
#
# Premise: fred covered his eyes with his hands, the wind was blowing sand
# around. he opened
# Focus: them when the wind stopped
# Referent:  them
# Answer: His eyes
# #when: fred covered ?x with his hands, the wind was blowing sand
# around. he opened
# #then: ?x when the wind stopped
#
# Premise: fred covered his eyes with his hands, the wind was blowing sand
# around. he lowered
# Focus: them when the wind stopped
# Referent:  them
# Answer: His hands
# #when: fred covered his eyes with ?x, the wind was blowing sand
# around. he lowered
# #then: ?x when the wind stopped
#
# Premise: the actress used to be named terpsichore she changed it to tina a
# few years ago, she figured
# Focus: it was too hard to pronounce
# Referent:  it
# Answer: Terpsichore
# #when: the actress used to be named ?x she changed it to tina a
# few years ago, she figured
# #then: ?x was too hard to pronounce
#
# Premise: the actress used to be named terpsichore she changed it to tina a
# few years ago, she figured
# Focus: it was easier to pronounce
# Referent:  it
# Answer: Tina
# #when: the actress used to be named terpsichore she changed it to ?x a
# few years ago, she figured
# #then: ?x was easier to pronounce
#
# Premise: fred watched tv while george went out to buy groceries. after an hour
# Focus: he got up
# Referent:  he
# Answer: Fred
# #when: ?x watched tv while george went out to buy groceries. after an hour
# #then: ?x got up
#
# Premise: fred watched tv while george went out to buy groceries. after an hour
# Focus: he got back
# Referent:  he
# Answer: George
# #when: fred watched tv while ?x went out to buy groceries. after an hour
# #then: ?x got back
#
# Premise: fred was supposed to run the dishwasher he put it off,
# he wanted to watch tv. but the show turned out to be boring, so he
# changed his mind and turned
# Focus: it on
# Referent:  it
# Answer: The dishwasher
# #when: fred was supposed to run ?x he put it off,
# he wanted to watch tv. but the show turned out to be boring, so he
# changed his mind and turned
# #then: ?x on
#
# Premise: fred was supposed to run the dishwasher he put it off,
# he wanted to watch tv. but the show turned out to be boring, so he
# changed his mind and turned
# Focus: it off
# Referent:  it
# Answer: The TV
# #when: fred was supposed to run the dishwasher he put it off,
# he wanted to watch tv. but the show turned out to be boring, so he
# changed his mind and turned
# #then: ?x off
#
# Premise: fred is the only man still alive who remembers my great-grandfather.
# Focus: He is a remarkable man
# Referent:  He
# Answer: Fred
# #when: ?x is the only man still alive who remembers my great-grandfather.
# #then: ?x is a remarkable man
#
# Premise: fred is the only man still alive who remembers my great-grandfather.
# Focus: He was a remarkable man
# Referent:  He
# Answer: My great-grandfather
# #when: fred is the only man still alive who remembers ?x.
# #then: ?x was a remarkable man
#
# Premise: fred is the only man alive who still remembers my father as an infant.
# when fred first saw my father,
# Focus: he was twelve years old
# Referent:  he
# Answer: Fred
# #when: ?x is the only man alive who still remembers my father as an infant.
# when ?x first saw my father,
# #then: ?x was twelve years old
#
# Premise: fred is the only man alive who still remembers my father as an infant.
# when fred first saw my father,
# Focus: he was twelve months old
# Referent:  he
# Answer: My father
# #when: fred is the only man alive who still remembers ?x as an infant.
# when fred first saw ?x,
# #then: ?x was twelve months old
#
# Premise: in july, kamtchatka declared war on yakutsk. since yakutsk's army was much
# better equipped and ten times larger,
# Focus: they were defeated within weeks
# Referent:  they
# Answer: Kamchatka
# #when: in july, kamtchatka declared war on yakutsk. since yakutsk's army was much
# better equipped and ten times larger,
# #then: ?x were defeated within weeks
#
# Premise: in july, kamtchatka declared war on yakutsk. since yakutsk's army was much
# better equipped and ten times larger,
# Focus: they were victorious within weeks
# Referent:  they
# Answer: Yakutsk
# #when: in july, kamtchatka declared war on ?x. since ?x's army was much
# better equipped and ten times larger,
# #then: ?x were victorious within weeks
#
# Premise: look! there is a minnow swimming right below that duck!
# Focus: It had better get away to safety fast!
# Referent:  It
# Answer: The minnow
# #when: look! there is a minnow swimming right below that duck!
# #then: ?x had better get away to safety fast!
#
# Premise: look! there is a shark swimming right below that duck!
# Focus: It had better get away to safety fast!
# Referent:  It
# Answer: The duck
# #when: look! there is a shark swimming right below that duck!
# #then: ?x had better get away to safety fast!
#
# Premise: archaeologists have concluded that humans lived in laputa 20,000 years ago.
# Focus: They hunted for evidence on the river banks
# Referent:  They
# Answer: Archaeologists
# #when: ?x have concluded that humans lived in laputa 20,000 years ago.
# #then: ?x hunted for evidence on the river banks
#
# Premise: archaeologists have concluded that humans lived in laputa 20,000 years ago.
# Focus: They hunted for deer on the river banks
# Referent:  They
# Answer: Prehistoric humans
# #when: archaeologists have concluded that humans lived in laputa 20,000 years ago.
# #then: ?x hunted for deer on the river banks
#
# Premise: the scientists are studying three species of fish that have recently
# been found living in the indian ocean.
# Focus: They began two years ago
# Referent:  They
# Answer: The scientists
# #when: ?x are studying three species of fish that have recently
# been found living in the indian ocean.
# #then: ?x began two years ago
#
# Premise: the scientists are studying three species of fish that have recently
# been found living in the indian ocean.
# Focus: They appeared two years ago
# Referent:  They
# Answer: The fish
# #when: the scientists are studying three species of fish that have recently
# been found living in the indian ocean.
# #then: ?x appeared two years ago
#
# Premise: the journalists interviewed the stars of the new movie.
# Focus: They were very persistent, so the interview lasted for a long time
# Referent:  They
# Answer: The journalists
# #when: ?x interviewed the stars of the new movie.
# #then: ?x were very persistent, so the interview lasted for a long time
#
# Premise: the journalists interviewed the stars of the new movie.
# Focus: They were very cooperative, so the interview lasted for a long time
# Referent:  They
# Answer: The stars
# #when: the journalists interviewed ?x of the new movie.
# #then: ?x were very cooperative, so the interview lasted for a long time
#
# Premise: the police arrested all of the gang members.
# Focus: They were trying to stop the drug trade in the neighborhood
# Referent:  They
# Answer: The police
# #when: ?x arrested all of the gang members.
# #then: ?x were trying to stop the drug trade in the neighborhood
#
# Premise: the police arrested all of the gang members.
# Focus: They were trying to run the drug trade in the neighborhood
# Referent:  They
# Answer: The gang members
# #when: the police arrested all of ?x.
# #then: ?x were trying to run the drug trade in the neighborhood
#
# Premise: i put the cake away in the refrigerator.
# Focus: It has a lot of butter in it
# Referent:  It
# Answer: The cake
# #when: i put ?x away in the refrigerator.
# #then: ?x has a lot of butter in it
#
# Premise: i put the cake away in the refrigerator.
# Focus: It has a lot of leftovers in it
# Referent:  It
# Answer: The refrigerator
# #when: i put the cake away in ?x.
# #then: ?x has a lot of leftovers in it
#
# Premise: sam broke both his ankles and he's walking with crutches. but a month
# or so from now
# Focus: they should be better
# Referent:  they
# Answer: The ankles
# #when: sam broke both his ankles and he's walking with crutches. but a month
# or so from now
# #then: ?x should be better
#
# Premise: sam broke both his ankles and he's walking with crutches. but a month
# or so from now
# Focus: they should be unnecessary
# Referent:  they
# Answer: The crutches
# #when: sam broke both his ankles and he's walking with crutches. but a month
# or so from now
# #then: ?x should be unnecessary
#
# Premise: when the sponsors of the bill got to the town hall, they were surprised
# to find that the room was full of opponents.
# Focus: They were very much in the minority
# Referent:  They
# Answer: The sponsors
# #when: when ?x of the bill got to the town hall, they were surprised
# to find that the room was full of opponents.
# #then: ?x were very much in the minority
#
# Premise: when the sponsors of the bill got to the town hall, they were surprised
# to find that the room was full of opponents.
# Focus: They were very much in the majority
# Referent:  They
# Answer: The opponents
# #when: when the sponsors of the bill got to the town hall, they were surprised
# to find that the room was full of opponents.
# #then: ?x were very much in the majority
#
# Premise: everyone really loved the oatmeal cookies; only a few people liked the
# chocolate chip cookies. next time, we should make more of
# Focus: them
# Referent:  them
# Answer: The oatmeal cookies
# #when: everyone really loved ?x; only a few people liked the
# chocolate chip cookies. next time, we should make more of
# #then: ?x
#
# Premise: everyone really loved the oatmeal cookies; only a few people liked the
# chocolate chip cookies. next time, we should make fewer of
# Focus: them
# Referent:  them
# Answer: The chocolate chip cookies
# #when: everyone really loved the oatmeal cookies; only a few people liked the
# chocolate chip cookies. next time, we should make fewer of
# #then: ?x
#
# Premise: we had hoped to place copies of our newsletter on all the chairs in the
# auditorium there were simply not enough of
# Focus: them
# Referent:  them
# Answer: copies of the newsletter
# #when: we had hoped to place copies of our newsletter on all the chairs in the
# auditorium there were simply not enough of
# #then: ?x
#
# Premise: we had hoped to place copies of our newsletter on all the chairs in the
# auditorium there were simply too many of
# Focus: them
# Referent:  them
# Answer: chairs
# #when: we had hoped to place copies of our newsletter on all the ?x in the
# auditorium there were simply too many of
# #then: ?x
#
# Premise: i stuck a pin through a carrot. when i pulled the pin out,
# Focus: it left a hole
# Referent:  it
# Answer: The pin
# #when: i stuck a pin through a carrot. when i pulled ?x out,
# #then: ?x left a hole
#
# Premise: i stuck a pin through a carrot. when i pulled the pin out,
# Focus: it had a hole
# Referent:  it
# Answer: The carrot
# #when: i stuck a pin through a carrot. when i pulled the pin out,
# #then: ?x had a hole
#
# Premise: i couldn't find a spoon, so i tried using a pen to stir my
# coffee. but that turned out to be a bad idea,
# Focus: it got full of coffee
# Referent:  it
# Answer: The pen
# #when: i couldn't find a spoon, so i tried using a pen to stir my
# coffee. but that turned out to be a bad idea,
# #then: ?x got full of coffee
#
# Premise: i couldn't find a spoon, so i tried using a pen to stir my
# coffee. but that turned out to be a bad idea,
# Focus: it got full of ink
# Referent:  it
# Answer: The coffee
# #when: i couldn't find a spoon, so i tried using a pen to stir my
# coffee. but that turned out to be a bad idea,
# #then: ?x got full of ink
#
# Premise: steve follows fred's example in everything.
# Focus: He admires him hugely
# Referent:  He
# Answer: Steve
# #when: ?x follows fred's example in everything.
# #then: ?x admires him hugely
#
# Premise: steve follows fred's example in everything.
# Focus: He influences him hugely
# Referent:  He
# Answer: Fred
# #when: steve follows ?x's example in everything.
# #then: ?x influences him hugely
#
# Premise: the table won't fit through the doorway
# Focus: it is too wide
# Referent:  it
# Answer: The table
# #when: ?x won't fit through the doorway
# #then: ?x is too wide
#
# Premise: the table won't fit through the doorway
# Focus: it is too narrow
# Referent:  it
# Answer: The doorway
# #when: the table won't fit through ?x
# #then: ?x is too narrow
#
# Premise: grace was happy to trade me her sweater for my jacket. she thinks
# Focus: it looks dowdy on her
# Referent:  it
# Answer: The sweater
# #when: grace was happy to trade me her sweater for my jacket. she thinks
# #then: ?x looks dowdy on her
#
# Premise: grace was happy to trade me her sweater for my jacket. she thinks
# Focus: it looks great on her
# Referent:  it
# Answer: The jacket
# #when: grace was happy to trade me her sweater for my jacket. she thinks
# #then: ?x looks great on her
#
# Premise: john hired bill to take care of
# Focus: him
# Referent:  him
# Answer: John
# #when: ?x hired bill to take care of
# #then: ?x
#
# Premise: john hired himself out to bill to take care of
# Focus: him
# Referent:  him
# Answer: Bill
# ...
# Referent:  he
# Answer: Bill
# #when: john ordered ?x to leave, so an hour later
# #then: ?x left
#
# Premise: sam goodman's biography of the spartan general xenophanes
# conveys a vivid sense of the difficulties
# Focus: he faced in his research
# Referent:  he
# Answer: Goodman
# #when: sam ?x's biography of the spartan general xenophanes
# conveys a vivid sense of the difficulties
# #then: ?x faced in his research
#
# Premise: sam goodman's biography of the spartan general xenophanes
# conveys a vivid sense of the difficulties
# Focus: he faced in his childhood
# Referent:  he
# Answer: Xenophanes
# #when: sam goodman's biography of the spartan general ?x
# conveys a vivid sense of the difficulties
# #then: ?x faced in his childhood
#
# Premise: emma's mother had died long ago, and
# Focus: her education had been managed by an excellent woman as governess
# Referent:  her
# Answer: Emma
# #when: ?x's mother had died long ago, and
# #then: ?x education had been managed by an excellent woman as governess
#
# Premise: emma's mother had died long ago, and
# Focus: her place had been taken by an excellent woman as governess
# Referent:  her
# Answer: Emma's mother
# #when: ?x had died long ago, and
# #then: ?x place had been taken by an excellent woman as governess
#
# Premise: jane knocked on susan's door but
# Focus: she did not get an answer
# Referent:  she
# Answer: Jane
# #when: ?x knocked on susan's door but
# #then: ?x did not get an answer
#
# Premise: jane knocked on susan's door but
# Focus: she did not answer
# Referent:  she
# Answer: Susan
# #when: jane knocked on ?x's door but
# #then: ?x did not answer
#
# Premise: joe paid the detective after
# Focus: he received the final report on the case
# Referent:  he
# Answer: Joe
# #when: ?x paid the detective after
# #then: ?x received the final report on the case
#
# Premise: joe paid the detective after
# Focus: he delivered the final report on the case
# Referent:  he
# Answer: the detective
# #when: joe paid ?x after
# #then: ?x delivered the final report on the case
#
# Premise: beth didn't get angry with sally, who had cut her off,
# Focus: she stopped and counted to ten
# Referent:  she
# Answer: Beth
# #when: ?x didn't get angry with sally, who had cut her off,
# #then: ?x stopped and counted to ten
#
# Premise: beth didn't get angry with sally, who had cut her off,
# Focus: she stopped and apologized
# Referent:  she
# Answer: Sally
# #when: beth didn't get angry with ?x, who had cut her off,
# #then: ?x stopped and apologized
#
# Premise: jim signaled the barman and gestured toward
# Focus: his empty glass
# Referent:  his
# Answer: Jim
# #when: ?x signaled the barman and gestured toward
# #then: ?x empty glass
#
# Premise: jim signaled the barman and gestured toward
# Focus: his bathroom key
# Referent:  his
# Answer: The barman
# #when: jim signaled ?x and gestured toward
# #then: ?x bathroom key
#
# Premise: dan took the rear seat while bill claimed the front
# Focus: his "Dibs!" was slow
# Referent:  his
# Answer: Dan
# #when: ?x took the rear seat while bill claimed the front
# #then: ?x "Dibs!" was slow
#
# Premise: dan took the rear seat while bill claimed the front
# Focus: his "Dibs!" was quicker
# Referent:  his
# Answer: Bill
# #when: dan took the rear seat while ?x claimed the front
# #then: ?x "Dibs!" was quicker
#
# Premise: tom said "check" to ralph as he moved
# Focus: his bishop
# Referent:  his
# Answer: Tom
# #when: ?x said "check" to ralph as he moved
# #then: ?x bishop
#
# Premise: tom said "check" to ralph as he took
# Focus: his bishop
# Referent:  his
# Answer: Ralph
# #when: tom said "check" to ?x as he took
# #then: ?x bishop
#
# Premise: as andrea in the crop duster passed over susan,
# Focus: she could see the landing strip
# Referent:  she
# Answer: Andrea
# #when: as ?x in the crop duster passed over susan,
# #then: ?x could see the landing strip
#
# Premise: as andrea in the crop duster passed over susan,
# Focus: she could see the landing gear
# Referent:  she
# Answer: Susan
# #when: as andrea in the crop duster passed over ?x,
# #then: ?x could see the landing gear
#
# Premise: tom gave ralph a lift to school so
# Focus: he wouldn't have to drive alone
# Referent:  he
# Answer: Tom
# #when: ?x gave ralph a lift to school so
# #then: ?x wouldn't have to drive alone
#
# Premise: tom gave ralph a lift to school so
# Focus: he wouldn't have to walk
# Referent:  he
# Answer: Ralph
# #when: tom gave ?x a lift to school so
# #then: ?x wouldn't have to walk
#
# Premise: bill passed the half-empty plate to john
# Focus: he was full
# Referent:  he
# Answer: Bill
# #when: ?x passed the half-empty plate to john
# #then: ?x was full
#
# Premise: bill passed the half-empty plate to john
# Focus: he was hungry
# Referent:  he
# Answer: John
# #when: bill passed the half-empty plate to ?x
# #then: ?x was hungry
#
# Premise: bill passed the gameboy to john
# Focus: his turn was over
# Referent:  his
# Answer: Bill
# #when: ?x passed the gameboy to john
# #then: ?x turn was over
#
# Premise: bill passed the gameboy to john
# Focus: his turn was next
# Referent:  his
# Answer: John
# #when: bill passed the gameboy to ?x
# #then: ?x turn was next
#
# Premise: the man lifted the boy onto
# Focus: his shoulders
# Referent:  his
# Answer: The man
# #when: ?x lifted the boy onto
# #then: ?x shoulders
#
# Premise: the man lifted the boy onto
# Focus: his bunk bed
# Referent:  his
# Answer: The boy
# #when: the man lifted ?x onto
# #then: ?x bunk bed
#
# Premise: stretching
# Focus: her back, the woman smiled at the girl
# Referent:  her
# Answer: The woman
# #when: stretching
# #then: ?x back, the woman smiled at the girl
#
# Premise: patting
# Focus: her back, the woman smiled at the girl
# Referent:  her
# Answer: The girl
# #when: patting
# #then: ?x back, the woman smiled at the girl
#
# Premise: billy cried toby wouldn't accept
# Focus: his toy
# Referent:  his
# Answer: Billy
# #when: ?x cried toby wouldn't accept
# #then: ?x toy
#
# Premise: billy cried toby wouldn't share
# Focus: his toy
# Referent:  his
# Answer: Toby
# #when: billy cried ?x wouldn't share
# #then: ?x toy
#
# Premise: lily spoke to donna, breaking
# Focus: her silence
# Referent:  her
# Answer: Lily
# #when: ?x spoke to donna, breaking
# #then: ?x silence
#
# Premise: lily spoke to donna, breaking
# Focus: her concentration
# Referent:  her
# Answer: Donna
# #when: lily spoke to ?x, breaking
# #then: ?x concentration
#
# Premise: when tommy dropped his ice cream, timmy giggled, so father gave
# Focus: him a sympathetic look
# Referent:  him
# Answer: Tommy
# #when: when ?x dropped his ice cream, timmy giggled, so father gave
# #then: ?x a sympathetic look
#
# Premise: when tommy dropped his ice cream, timmy giggled, so father gave
# Focus: him a stern look
# Referent:  him
# Answer: Timmy
# #when: when tommy dropped his ice cream, ?x giggled, so father gave
# #then: ?x a stern look
#
# Premise: as ollie carried tommy up the long winding steps,
# Focus: his legs ached
# Referent:  his
# Answer: Ollie
# #when: as ?x carried tommy up the long winding steps,
# #then: ?x legs ached
#
# Premise: as ollie carried tommy up the long winding steps,
# Focus: his legs dangled
# Referent:  his
# Answer: Tommy
# #when: as ollie carried ?x up the long winding steps,
# #then: ?x legs dangled
#
# Premise: the father carried the sleeping boy in
# Focus: his arms
# Referent:  his
# Answer: The father
# #when: ?x carried the sleeping boy in
# #then: ?x arms
#
# Premise: the father carried the sleeping boy in
# Focus: his bassinet
# Referent:  his
# Answer: The boy
# #when: the father carried the sleeping boy in
# #then: ?x bassinet
#
# Premise: the woman held the girl against
# Focus: her chest
# Referent:  her
# Answer: The woman
# #when: ?x held the girl against
# #then: ?x chest
#
# Premise: the woman held the girl against
# Focus: her will
# Referent:  her
# Answer: The girl
# #when: the woman held ?x against
# #then: ?x will
#
# Premise: pam's parents came home and found her having sex with her boyfriend, paul.
# Focus: They were furious about it
# Referent:  They
# Answer: Pam's parents
# #when: ?x came home and found her having sex with her boyfriend, paul.
# #then: ?x were furious about it
#
# Premise: pam's parents came home and found her having sex with her boyfriend, paul.
# Focus: They were embarrassed about it
# Referent:  They
# Answer: Pam and Paul
# #when: pam's parents came home and found her having sex with her boyfriend, paul.
# #then: ?x were embarrassed about it
#
# Premise: dr. adams informed kate that
# Focus: she had retired and presented several options for future treatment
# Referent:  she
# Answer: Dr. Adams
# #when: ?x informed kate that
# #then: ?x had retired and presented several options for future treatment
#
# Premise: dr. adams informed kate that
# Focus: she had cancer and presented several options for future treatment
# Referent:  she
# Answer: Kate
# #when: dr. adams informed ?x that
# #then: ?x had cancer and presented several options for future treatment
#
# Premise: dan had to stop bill from toying with the injured bird.
# Focus: He is very compassionate
# Referent:  He
# Answer: Dan
# #when: ?x had to stop bill from toying with the injured bird.
# #then: ?x is very compassionate
#
# Premise: dan had to stop bill from toying with the injured bird.
# Focus: He is very cruel
# Referent:  He
# Answer: Bill
# #when: dan had to stop ?x from toying with the injured bird.
# #then: ?x is very cruel
#
# Premise: george got free tickets to the play he gave them to eric, even though
# Focus: he was particularly eager to see it
# Referent:  he
# Answer: George
# #when: ?x got free tickets to the play he gave them to eric, even though
# #then: ?x was particularly eager to see it
#
# Premise: george got free tickets to the play he gave them to eric,
# Focus: he was particularly eager to see it
# Referent:  he
# Answer: Eric
# #when: george got free tickets to the play he gave them to ?x,
# #then: ?x was particularly eager to see it
#
# Premise: george got free tickets to the play he gave them to eric,
# Focus: he was not particularly eager to see it
# Referent:  he
# Answer: George
# #when: ?x got free tickets to the play he gave them to eric,
# #then: ?x was not particularly eager to see it
#
# Premise: jane gave joan candy
# Focus: she wasn't hungry
# Referent:  she
# Answer: Jane
# #when: ?x gave joan candy
# #then: ?x wasn't hungry
#
# Premise: jane gave joan candy
# Focus: she was hungry
# Referent:  she
# Answer: Joan
# #when: jane gave ?x candy
# #then: ?x was hungry
#
# Premise: i tried to paint a picture of an orchard, with lemons in the lemon trees,
# but
# Focus: they came out looking more like light bulbs
# Referent:  they
# Answer: lemons
# #when: i tried to paint a picture of an orchard, with ?x in the lemon trees,
# but
# #then: ?x came out looking more like light bulbs
#
# Premise: i tried to paint a picture of an orchard, with lemons in the lemon trees,
# but
# Focus: they came out looking more like telephone poles
# Referent:  they
# Answer: lemon trees
# #when: i tried to paint a picture of an orchard, with lemons in the ?x,
# but
# #then: ?x came out looking more like telephone poles
#
# Premise: james asked robert for a favor but
# Focus: he was refused
# Referent:  he
# Answer: James
# #when: ?x asked robert for a favor but
# #then: ?x was refused
#
# Premise: james asked robert for a favor but
# Focus: he refused
# Referent:  he
# Answer: Robert
# #when: james asked ?x for a favor but
# #then: ?x refused
#
# Premise: kirilov ceded the presidency to shatov
# Focus: he was less popular
# Referent:  he
# Answer: Kirilov
# #when: ?x ceded the presidency to shatov
# #then: ?x was less popular
#
# Premise: kirilov ceded the presidency to shatov
# Focus: he was more popular
# Referent:  he
# Answer: Shatov
# #when: kirilov ceded the presidency to ?x
# #then: ?x was more popular
#
# Premise: emma did not pass the ball to janie although
# Focus: she saw that she was open
# Referent:  she
# Answer: Emma
# #when: ?x did not pass the ball to janie although
# #then: ?x saw that she was open
#
# Premise: emma did not pass the ball to janie although
# Focus: she was open
# Referent:  she
# Answer: Janie
# #when: emma did not pass the ball to ?x although
# #then: ?x was open
#
# Premise: i put the butterfly wing on the table and
# Focus: it broke
# Referent:  it
# Answer: The butterfly wing
# #when: i put ?x on the table and
# #then: ?x broke
#
# Premise: i put the heavy book on the table and
# Focus: it broke
# Referent:  it
# Answer: The table
# #when: i put the heavy book on ?x and
# #then: ?x broke
#
# Premise: madonna fired her trainer
# Focus: she couldn't stand her boyfriend
# Referent:  she
# Answer: Madonna
# #when: ?x fired her trainer
# #then: ?x couldn't stand her boyfriend
#
# Premise: madonna fired her trainer
# Focus: she slept with her boyfriend
# Referent:  she
# Answer: The trainer
# #when: madonna fired her trainer
# #then: ?x slept with her boyfriend
#
# Premise: madonna fired her trainer she slept with
# Focus: her boyfriend
# Referent:  her
# Answer: Madonna
# #when: ?x fired her trainer she slept with
# #then: ?x boyfriend
#
# Premise: madonna fired her trainer she couldn't stand
# Focus: her boyfriend
# Referent:  her
# Answer: The trainer
# #when: madonna fired her trainer she couldn't stand
# #then: ?x boyfriend
#
# Premise: carol believed that rebecca suspected that
# Focus: she had stolen the watch
# Referent:  she
# Answer: Carol
# #when: ?x believed that rebecca suspected that
# #then: ?x had stolen the watch
#
# Premise: carol believed that rebecca regretted that
# Focus: she had stolen the watch
# Referent:  she
# Answer: Rebecca
# #when: carol believed that ?x regretted that
# #then: ?x had stolen the watch
#
# Premise: this book introduced shakespeare to ovid; it was a major influence on
# Focus: his writing
# Referent:  his
# Answer: Shakespeare
# #when: this book introduced ?x to ovid; it was a major influence on
# #then: ?x writing
#
# Premise: this book introduced shakespeare to goethe; it was a major influence on
# Focus: his writing
# Referent:  his
# Answer: Goethe
# #when: this book introduced shakespeare to ?x; it was a major influence on
# #then: ?x writing
#
# Premise: this book introduced shakespeare to ovid; it was a fine selection of
# Focus: his writing
# Referent:  his
# Answer: Ovid
# #when: this book introduced shakespeare to ?x; it was a fine selection of
# #then: ?x writing
#
# Premise: this book introduced shakespeare to goethe; it was a fine selection of
# Focus: his writing
# Referent:  his
# Answer: Shakespeare
# #when: this book introduced ?x to goethe; it was a fine selection of
# #then: ?x writing
#
# Premise: alice looked for her friend jade in the crowd. since
# Focus: she always
# has good luck, Alice spotted her quickly
# Referent:  she
# Answer: Alice
# #when: ?x looked for her friend jade in the crowd. since
# #then: ?x always
# has good luck, Alice spotted her quickly
#
# Premise: alice looked for her friend jade in the crowd. since
# Focus: she always
# wears a red turban, Alice spotted her quickly
# Referent:  she
# Answer: Jade
# #when: alice looked for her friend ?x in the crowd. since
# #then: ?x always
# wears a red turban, Alice spotted her quickly
#
# Premise: during a game of tag, ethan chased luke
# Focus: he was "it"
# Referent:  he
# Answer: Ethan
# #when: during a game of tag, ?x chased luke
# #then: ?x was "it"
#
# Premise: during a game of tag, ethan ran from luke
# Focus: he was "it"
# Referent:  he
# Answer: Luke
# #when: during a game of tag, ethan ran from ?x
# #then: ?x was "it"
#
# Premise: at the loebner competition the judges couldn't figure out which respondents
# were the chatbots
# Focus: they were so stupid
# Referent:  they
# Answer: the judges
# #when: at the loebner competition ?x couldn't figure out which respondents
# were the chatbots
# #then: ?x were so stupid
#
# Premise: at the loebner competition the judges couldn't figure out which respondents
# were the chatbots
# Focus: they were so advanced
# Referent:  they
# Answer: the chatbots
# #when: at the loebner competition the judges couldn't figure out which respondents
# were ?x
# #then: ?x were so advanced
#
# Premise: the user changed his password from "grwqwu8jyc" toâ "willow-towered canopy
# huntertropic wrestles" as
# Focus: it was easy to forget
# Referent:  it
# Answer: GrWQWu8JyC
# #when: the user changed his password from "?x" toâ "willow-towered canopy
# huntertropic wrestles" as
# #then: ?x was easy to forget
#
# Premise: the user changed his password from "grwqwu8jyc" toâ "willow-towered canopy
# huntertropic wrestles" as
# Focus: it was easy to remember
# Referent:  it
# Answer: willow-towered Canopy
# Huntertropic wrestles
# #when: the user changed his password from "grwqwu8jyc" toâ "?x" as
# #then: ?x was easy to remember

# %% [markdown]
# ## Inspect the Rules

# %%
import pprint

for rule in rules:
    pprint.pprint(rule, sort_dicts=False)
# Out:
# {'#when': '?x refused the demonstrators a permit',
#  '#then': '?x feared violence'}
# {'#when': 'the city councilmen refused ?x a permit',
#  '#then': '?x advocated violence'}
# {'#when': "?x doesn't fit into the brown suitcase", '#then': '?x is too large'}
# {'#when': "the trophy doesn't fit into the brown suitcase",
#  '#then': '?x is too small'}
# {'#when': '?x made sure to thank susan for all the help',
#  '#then': '?x had recieved'}
# {'#when': 'joan made sure to thank ?x for all the help',
#  '#then': '?x had given'}
# {'#when': '?x tried to call george on the phone',
#  '#then': "?x wasn't successful"}
# {'#when': 'paul tried to call ?x on the phone', '#then': "?x wasn't available"}
# {'#when': '?x asked the witness a question',
#  '#then': '?x was reluctant to repeat it'}
# {'#when': 'the lawyer asked ?x a question',
#  '#then': '?x was reluctant to answer it'}
# {'#when': '?x zoomed by the school bus', '#then': '?x was going so fast'}
# {'#when': 'the delivery truck zoomed by ?x', '#then': '?x was going so slow'}
# {'#when': '?x felt vindicated when his longtime rival bill revealed that',
#  '#then': '?x was the winner of the competition'}
# {'#when': 'frank felt crushed when his longtime rival ?x revealed that',
#  '#then': '?x was the winner of the competition'}
# {'#when': "?x couldn't lift his son", '#then': '?x was so weak'}
# {'#when': "the man couldn't lift his son", '#then': '?x was so heavy'}
# {'#when': '?x crashed right through the table', '#then': '?x was made of steel'}
# {'#when': 'the large ball crashed right through ?x',
#  '#then': '?x was made of styrofoam'}
# {'#when': "?x couldn't see the stage with billy in front of him",
#  '#then': '?x is so short'}
# {'#when': "john couldn't see the stage with ?x in front of him",
#  '#then': '?x is so tall'}
# {'#when': '?x threw his schoolbag down to ray after',
#  '#then': '?x reached the top of the stairs'}
# {'#when': 'tom threw his schoolbag down to ?x after',
#  '#then': '?x reached the bottom of the stairs'}
# {'#when': 'although they ran at about the same speed, ?x beat sally',
#  '#then': '?x had such a good start'}
# {'#when': 'although they ran at about the same speed, sue beat ?x',
#  '#then': '?x had such a bad start'}
# {'#when': '?x rolled off the shelf', '#then': "?x wasn't anchored"}
# {'#when': 'the sculpture rolled off ?x', '#then': "?x wasn't level"}
# {'#when': "?x was hung just above tina's and",
#  '#then': '?x did look much better with another one below it'}
# {'#when': "sam's drawing was hung just above tina's and",
#  '#then': '?x did look much better with another one above it'}
# {'#when': '?x did a lot better than her good friend lucy on the test',
#  '#then': '?x had studied so hard'}
# {'#when': 'anna did a lot worse than her good friend ?x on the test',
#  '#then': '?x had studied so hard'}
# {'#when': '?x arrived after the police',
#  '#then': '?x were coming from so far away'}
# {'#when': 'the firemen arrived before ?x',
#  '#then': '?x were coming from so far away'}
# {'#when': '?x was upset with tom the toaster',
#  '#then': "?x had bought from him didn't work"}
# {'#when': 'frank was upset with ?x the toaster',
#  '#then': "?x had sold him didn't work"}
# {'#when': '?x yelled at kevin', '#then': '?x was so upset'}
# {'#when': 'jim comforted ?x', '#then': '?x was so upset'}
# {'#when': '?x had been placed above\nthe bag of flour, so',
#  '#then': '?x had to be moved first'}
# {'#when': 'the sack of potatoes had been placed below\n?x, so',
#  '#then': '?x had to be moved first'}
# {'#when': '?x envies martin although', '#then': '?x is very successful'}
# {'#when': 'pete envies ?x', '#then': '?x is very successful'}
# {'#when': '?x were bullying the younger ones, so we punished', '#then': '?x'}
# {'#when': 'the older students were bullying the younger ones, so we rescued',
#  '#then': '?x'}
# {'#when': 'i poured water from ?x into the cup until', '#then': '?x was empty'}
# {'#when': 'i poured water from the bottle into ?x until',
#  '#then': '?x was full'}
# {'#when': "?x knows all about ann's personal problems", '#then': '?x is nosy'}
# {'#when': "susan knows all about ?x's personal problems",
#  '#then': '?x is indiscreet'}
# {'#when': '?x explained his theory to mark but',
#  '#then': "?x couldn't convince him"}
# {'#when': 'sid explained his theory to ?x but',
#  '#then': "?x couldn't understand him"}
# {'#when': "?x knew that ann's son had been in a car accident, so",
#  '#then': '?x told her about it'}
# {'#when': "susan knew that ?x's son had been in a car accident,",
#  '#then': '?x told her about it'}
# {'#when': "?x's uncle can still beat him at tennis, even though",
#  '#then': '?x is 30 years younger'}
# {'#when': '?x can still beat him at tennis, even though',
#  '#then': '?x is 30 years older'}
# {'#when': "?x in mark's living room shows an oak tree.",
#  '#then': '?x is to the right of the bookcase'}
# {'#when': "the painting in mark's living room shows an oak tree.",
#  '#then': '?x is to the right of a house'}
# {'#when': 'there is a gap in the wall. you can see the garden through',
#  '#then': '?x'}
# {'#when': 'there is a gap in ?x. you can see the garden behind', '#then': '?x'}
# {'#when': '?x is clogged with hair.', '#then': '?x has to be cleaned'}
# {'#when': 'the drain is clogged with hair.', '#then': '?x has to be removed'}
# {'#when': 'my meeting started at 4:00 and i needed to catch the train at '
#           '4:30, \n'
#           "so there wasn't much time. luckily,",
#  '#then': '?x was short, so it worked out'}
# {'#when': 'my meeting started at 4:00 and i needed to catch ?x at 4:30, \n'
#           "so there wasn't much time. luckily,",
#  '#then': '?x was delayed, so it worked out'}
# {'#when': "there is a pillar between me and the stage, and i can't see around",
#  '#then': '?x'}
# {'#when': "there is a pillar between me and ?x, and i can't see", '#then': '?x'}
# {'#when': 'they broadcast an announcement a subway came into the \n'
#           "station and i couldn't hear",
#  '#then': '?x'}
# {'#when': 'they broadcast an announcement a subway came into the \n'
#           "station and i couldn't hear over",
#  '#then': '?x'}
# {'#when': 'in the middle of the outdoor concert, the rain started falling',
#  '#then': '?x continued until 10'}
# {'#when': 'in the middle of the outdoor concert, ?x started falling, and',
#  '#then': '?x continued until 10'}
# {'#when': 'i used an old rag to clean the knife, and then i put',
#  '#then': '?x in the trash'}
# {'#when': 'i used an old rag to clean ?x, and then i put',
#  '#then': '?x in the drawer'}
# {'#when': '?x asked mary what time the library closes,',
#  '#then': '?x had forgotten'}
# {'#when': 'ann asked ?x what time the library closes',
#  '#then': '?x had forgotten'}
# {'#when': 'i took ?x out of the backpack so that', '#then': '?x would be handy'}
# {'#when': 'i took the water bottle out of ?x so that',
#  '#then': '?x would be lighter'}
# {'#when': "i couldn't put ?x on the shelf", '#then': '?x was too tall'}
# {'#when': "i couldn't put the pot on ?x", '#then': '?x was too high'}
# {'#when': "i'm sure that my map will show this building;",
#  '#then': '?x is very good'}
# {'#when': "i'm sure that my map will show this building;",
#  '#then': '?x is very famous'}
# {'#when': "?x paid for charlie's college education.",
#  '#then': '?x is very generous'}
# {'#when': "bob paid for ?x's college education.",
#  '#then': '?x is very grateful'}
# {'#when': "?x paid for charlie's college education now charlie acts as though\n"
#           'it never happened.',
#  '#then': '?x is very hurt'}
# {'#when': "bob paid for ?x's college education now ?x acts as though\n"
#           'it never happened.',
#  '#then': '?x is very ungrateful'}
# {'#when': "?x was playing cards with adam and was way ahead. if adam hadn't "
#           'had a\n'
#           'sudden run of good luck,',
#  '#then': '?x would have won'}
# {'#when': "bob was playing cards with ?x and was way ahead. if ?x hadn't had "
#           'a\n'
#           'sudden run of good luck,',
#  '#then': '?x would have lost'}
# {'#when': "?x can't leave work here until bob arrives to replace him. if bob "
#           'had \n'
#           'left home for work on time,',
#  '#then': '?x would be gone by this time'}
# {'#when': "adam can't leave work here until ?x arrives to replace him. if ?x "
#           'had \n'
#           'left home for work on time,',
#  '#then': '?x would be here by this time'}
# {'#when': 'if ?x has succeeded in fooling sam,',
#  '#then': '?x would have gotten a lot of money'}
# {'#when': 'if the con artist has succeeded in fooling ?x,',
#  '#then': '?x would have lost a lot of money'}
# {'#when': 'it was a summer afternoon, and ?x was sitting in the middle of the\n'
#           'lawn. after a while, it got up and moved to a spot under the '
#           'tree, \n'
#           'because',
#  '#then': '?x was hot'}
# {'#when': 'it was a summer afternoon, and the dog was sitting in the middle of '
#           'the\n'
#           'lawn. after a while, it got up and moved to a spot under the '
#           'tree, \n'
#           'because',
#  '#then': '?x was cooler'}
# {'#when': '?x was lying by the mouse hole waiting for the mouse',
#  '#then': '?x was too impatient'}
# {'#when': 'the cat was lying by ?x hole waiting for ?x',
#  '#then': '?x was too cautious'}
# {'#when': '?x gave birth to a daughter last month.',
#  '#then': '?x is a very charming woman'}
# {'#when': 'anne gave birth to a daughter last month.',
#  '#then': '?x is a very charming baby'}
# {'#when': '?x tried frantically to stop her daughter from chatting at\n'
#           'the party, leaving us to wonder why',
#  '#then': '?x was behaving so strangely'}
# {'#when': 'alice tried frantically to stop her daughter from barking at\n'
#           'the party, leaving us to wonder why',
#  '#then': '?x was behaving so strangely'}
# {'#when': 'i saw ?x yelling at some guy in a military uniform with a huge '
#           'red \n'
#           "beard. i don't know why",
#  '#then': '?x was, but he looked very unhappy'}
# {'#when': 'i saw jim yelling at some guy in a military uniform with a huge '
#           'red \n'
#           "beard. i don't know who",
#  '#then': '?x was, but he looked very unhappy'}
# {'#when': '?x ate the worm.', '#then': '?x was hungry'}
# {'#when': 'the fish ate ?x.', '#then': '?x was tasty'}
# {'#when': 'i was trying to open the lock with ?x someone had filled the \n'
#           "keyhole with chewing gum, and i couldn't get",
#  '#then': '?x in'}
# {'#when': 'i was trying to open the lock with the key someone had filled the \n'
#           "keyhole with chewing gum, and i couldn't get",
#  '#then': '?x out'}
# {'#when': '?x chased the cat, which ran up a tree.',
#  '#then': '?x waited at the bottom'}
# {'#when': 'the dog chased ?x, which ran up a tree.',
#  '#then': '?x waited at the top'}
# {'#when': 'in the storm, ?x fell down and crashed through the roof of my \n'
#           'house. now, i have to get',
#  '#then': '?x removed'}
# {'#when': 'in the storm, the tree fell down and crashed through ?x of my \n'
#           'house. now, i have to get',
#  '#then': '?x repaired'}
# {'#when': '?x walked into the bank and stabbed one of the tellers.',
#  '#then': '?x was immediately taken to the police station'}
# {'#when': 'the customer walked into the bank and stabbed one of ?xs.',
#  '#then': '?x was immediately taken to the hospital'}
# {'#when': '?x was doing research in the library when he heard a man humming '
#           'and \n'
#           'whistling.',
#  '#then': '?x was very annoyed'}
# {'#when': 'john was doing research in the library when he heard a man humming '
#           'and \n'
#           'whistling.',
#  '#then': '?x was very annoying'}
# {'#when': '?x was jogging through the park when he saw a man juggling '
#           'watermelons.',
#  '#then': '?x was very impressed'}
# {'#when': 'john was jogging through the park when he saw a man juggling '
#           'watermelons.',
#  '#then': '?x was very impressive'}
# {'#when': '?x collapsed on the sidewalk. soon he saw carl coming to help.',
#  '#then': '?x was very ill'}
# {'#when': 'bob collapsed on the sidewalk. soon he saw ?x coming to help.',
#  '#then': '?x was very concerned'}
# {'#when': "?x are passionately in love amy's parents are unhappy\nabout it,",
#  '#then': '?x are fifteen'}
# {'#when': 'sam and amy are passionately in love ?x are unhappy\nabout it,',
#  '#then': '?x are snobs'}
# {'#when': '?x told pete many lies about himself, which pete included in his '
#           'book.',
#  '#then': '?x should have been more  truthful'}
# {'#when': 'mark told ?x many lies about himself, which ?x included in his '
#           'book.',
#  '#then': '?x should have been more  skeptical'}
# {'#when': 'joe has sold his house and bought a new one a few miles away. he '
#           'will\n'
#           'be moving out of',
#  '#then': '?x on Thursday'}
# {'#when': 'joe has sold his house and bought a new one a few miles away. he '
#           'will\n'
#           'be moving into',
#  '#then': '?x on Thursday'}
# {'#when': "many ?x start to read paul's books and can't put them down.",
#  '#then': '?x are gripped because Paul writes so well'}
# {'#when': "many people start to read ?x and can't put them down.",
#  '#then': '?x are popular because Paul writes so well'}
# {'#when': 'mary took out her flute and played one of her favorite pieces. she\n'
#           'has had',
#  '#then': '?x since she was a child'}
# {'#when': 'mary took out her flute and played one of her favorite pieces. she\n'
#           'has loved',
#  '#then': '?x since she was a child'}
# {'#when': 'sam pulled up a chair to the piano',
#  '#then': '?x was broken, so he had to stand instead'}
# {'#when': 'sam pulled up a chair to ?x',
#  '#then': '?x was broken, so he had to sing instead'}
# {'#when': 'since it was raining, i carried ?x in my backpack to keep',
#  '#then': '?x dry'}
# {'#when': 'since it was raining, i carried the newspaper over my backpack to '
#           'keep',
#  '#then': '?x dry'}
# {'#when': 'sara borrowed ?x from the library she needs it for an\n'
#           'article she is working on. she reads',
#  '#then': '?x when she gets home from work'}
# {'#when': 'sara borrowed the book from the library she needs it for an\n'
#           'article she is working on. she writes',
#  '#then': '?x when she gets home from work'}
# {'#when': 'this morning, joey built a sand castle on the beach, and put a '
#           'toy \n'
#           'flag in the highest tower this afternoon the tide \n'
#           'knocked',
#  '#then': '?x down'}
# {'#when': 'this morning, joey built a sand castle on the beach, and put a '
#           'toy \n'
#           'flag in the highest tower this afternoon the wind \n'
#           'knocked',
#  '#then': '?x down'}
# {'#when': "?x knocked on susan's door there was no answer.",
#  '#then': '?x was disappointed'}
# {'#when': "jane knocked on ?x's door there was no answer.",
#  '#then': '?x was out'}
# {'#when': '?x knocked on the door, and susan answered it.',
#  '#then': '?x invited her to come out'}
# {'#when': 'jane knocked on the door, and ?x answered it.',
#  '#then': '?x invited her to come in'}
# {'#when': '?x took french classes from adam,',
#  '#then': '?x was eager to speak it fluently'}
# {'#when': 'sam took french classes from ?x,',
#  '#then': '?x was known to speak it fluently'}
# {'#when': "?x to the lake was blocked, so we couldn't use", '#then': '?x'}
# {'#when': "the path to ?x was blocked, so we couldn't reach", '#then': '?x'}
# {'#when': '?x was covered by a thick cloud all morning luckily, by the time\n'
#           'the picnic started,',
#  '#then': '?x was out'}
# {'#when': 'the sun was covered by a thick cloud all morning luckily, by the '
#           'time\n'
#           'the picnic started,',
#  '#then': '?x was gone'}
# {'#when': 'we went to ?x, a shark had been seen at the ocean beach, so',
#  '#then': '?x was a safer place to swim'}
# {'#when': 'we went to the lake, a shark had been seen at ?x, so',
#  '#then': '?x was a dangerous place to swim'}
# {'#when': 'sam tried to paint a picture of shepherds with sheep',
#  '#then': '?x ended up looking more like golfers'}
# {'#when': 'sam tried to paint a picture of shepherds with sheep',
#  '#then': '?x ended up looking more like dogs'}
# {'#when': '?x tucked her daughter anne into bed, so that',
#  '#then': '?x could work'}
# {'#when': 'mary tucked her daughter anne into bed, so that',
#  '#then': '?x could sleep'}
# {'#when': '?x had very warm down coats',
#  '#then': '?x were not prepared for the cold in Alaska'}
# {'#when': 'fred and alice had very warm down ?x',
#  '#then': '?x were not enough for the cold in Alaska'}
# {'#when': "?x visited cooper's grave in 1765. at that date",
#  '#then': '?x had been travelling for five years'}
# {'#when': "thomson visited ?x's grave in 1765. at that date",
#  '#then': '?x had been dead for five years'}
# {'#when': '?x was greatly influenced by arnold, though',
#  '#then': '?x lived two centuries later'}
# {'#when': 'jackson was greatly influenced by ?x, though',
#  '#then': '?x lived two centuries earlier'}
# {'#when': "i can't cut that tree down with that axe;",
#  '#then': '?x is too thick'}
# {'#when': "i can't cut that tree down with that axe;",
#  '#then': '?x is too small'}
# {'#when': '?x are getting in at night and attacking the chickens. i shall '
#           'have\n'
#           'to kill',
#  '#then': '?x'}
# {'#when': 'the foxes are getting in at night and attacking ?x. i shall have\n'
#           'to guard',
#  '#then': '?x'}
# {'#when': '?x are getting in at night and attacking the chickens.',
#  '#then': '?x have gotten very bold'}
# {'#when': 'the foxes are getting in at night and attacking ?x.',
#  '#then': '?x have gotten very nervous'}
# {'#when': 'fred covered ?x with his hands, the wind was blowing sand\n'
#           'around. he opened',
#  '#then': '?x when the wind stopped'}
# {'#when': 'fred covered his eyes with ?x, the wind was blowing sand\n'
#           'around. he lowered',
#  '#then': '?x when the wind stopped'}
# {'#when': 'the actress used to be named ?x she changed it to tina a \n'
#           'few years ago, she figured',
#  '#then': '?x was too hard to pronounce'}
# {'#when': 'the actress used to be named terpsichore she changed it to ?x a \n'
#           'few years ago, she figured',
#  '#then': '?x was easier to pronounce'}
# {'#when': '?x watched tv while george went out to buy groceries. after an hour',
#  '#then': '?x got up'}
# {'#when': 'fred watched tv while ?x went out to buy groceries. after an hour',
#  '#then': '?x got back'}
# {'#when': 'fred was supposed to run ?x he put it off, \n'
#           'he wanted to watch tv. but the show turned out to be boring, so he\n'
#           'changed his mind and turned',
#  '#then': '?x on'}
# {'#when': 'fred was supposed to run the dishwasher he put it off, \n'
#           'he wanted to watch tv. but the show turned out to be boring, so he\n'
#           'changed his mind and turned',
#  '#then': '?x off'}
# {'#when': '?x is the only man still alive who remembers my great-grandfather.',
#  '#then': '?x is a remarkable man'}
# {'#when': 'fred is the only man still alive who remembers ?x.',
#  '#then': '?x was a remarkable man'}
# {'#when': '?x is the only man alive who still remembers my father as an '
#           'infant.\n'
#           'when ?x first saw my father,',
#  '#then': '?x was twelve years old'}
# {'#when': 'fred is the only man alive who still remembers ?x as an infant.\n'
#           'when fred first saw ?x,',
#  '#then': '?x was twelve months old'}
# {'#when': "in july, kamtchatka declared war on yakutsk. since yakutsk's army "
#           'was much \n'
#           'better equipped and ten times larger,',
#  '#then': '?x were defeated within weeks'}
# {'#when': "in july, kamtchatka declared war on ?x. since ?x's army was much \n"
#           'better equipped and ten times larger,',
#  '#then': '?x were victorious within weeks'}
# {'#when': 'look! there is a minnow swimming right below that duck!',
#  '#then': '?x had better get away to safety fast!'}
# {'#when': 'look! there is a shark swimming right below that duck!',
#  '#then': '?x had better get away to safety fast!'}
# {'#when': '?x have concluded that humans lived in laputa 20,000 years ago.',
#  '#then': '?x hunted for evidence on the river banks'}
# {'#when': 'archaeologists have concluded that humans lived in laputa 20,000 '
#           'years ago.',
#  '#then': '?x hunted for deer on the river banks'}
# {'#when': '?x are studying three species of fish that have recently\n'
#           'been found living in the indian ocean.',
#  '#then': '?x began two years ago'}
# {'#when': 'the scientists are studying three species of fish that have '
#           'recently\n'
#           'been found living in the indian ocean.',
#  '#then': '?x appeared two years ago'}
# {'#when': '?x interviewed the stars of the new movie.',
#  '#then': '?x were very persistent, so the interview lasted for a long time'}
# {'#when': 'the journalists interviewed ?x of the new movie.',
#  '#then': '?x were very cooperative, so the interview lasted for a long time'}
# {'#when': '?x arrested all of the gang members.',
#  '#then': '?x were trying to stop the drug trade in the neighborhood'}
# {'#when': 'the police arrested all of ?x.',
#  '#then': '?x were trying to run the drug trade in the neighborhood'}
# {'#when': 'i put ?x away in the refrigerator.',
#  '#then': '?x has a lot of butter in it'}
# {'#when': 'i put the cake away in ?x.',
#  '#then': '?x has a lot of leftovers in it'}
# {'#when': "sam broke both his ankles and he's walking with crutches. but a "
#           'month\n'
#           'or so from now',
#  '#then': '?x should be better'}
# {'#when': "sam broke both his ankles and he's walking with crutches. but a "
#           'month\n'
#           'or so from now',
#  '#then': '?x should be unnecessary'}
# {'#when': 'when ?x of the bill got to the town hall, they were surprised\n'
#           'to find that the room was full of opponents.',
#  '#then': '?x were very much in the minority'}
# {'#when': 'when the sponsors of the bill got to the town hall, they were '
#           'surprised\n'
#           'to find that the room was full of opponents.',
#  '#then': '?x were very much in the majority'}
# {'#when': 'everyone really loved ?x; only a few people liked the \n'
#           'chocolate chip cookies. next time, we should make more of',
#  '#then': '?x'}
# {'#when': 'everyone really loved the oatmeal cookies; only a few people liked '
#           'the \n'
#           'chocolate chip cookies. next time, we should make fewer of',
#  '#then': '?x'}
# {'#when': 'we had hoped to place copies of our newsletter on all the chairs in '
#           'the\n'
#           'auditorium there were simply not enough of',
#  '#then': '?x'}
# {'#when': 'we had hoped to place copies of our newsletter on all the ?x in '
#           'the\n'
#           'auditorium there were simply too many of',
#  '#then': '?x'}
# {'#when': 'i stuck a pin through a carrot. when i pulled ?x out,',
#  '#then': '?x left a hole'}
# {'#when': 'i stuck a pin through a carrot. when i pulled the pin out,',
#  '#then': '?x had a hole'}
# {'#when': "i couldn't find a spoon, so i tried using a pen to stir my \n"
#           'coffee. but that turned out to be a bad idea,',
#  '#then': '?x got full of coffee'}
# {'#when': "i couldn't find a spoon, so i tried using a pen to stir my \n"
#           'coffee. but that turned out to be a bad idea,',
#  '#then': '?x got full of ink'}
# {'#when': "?x follows fred's example in everything.",
#  '#then': '?x admires him hugely'}
# {'#when': "steve follows ?x's example in everything.",
#  '#then': '?x influences him hugely'}
# {'#when': "?x won't fit through the doorway", '#then': '?x is too wide'}
# {'#when': "the table won't fit through ?x", '#then': '?x is too narrow'}
# {'#when': 'grace was happy to trade me her sweater for my jacket. she thinks',
#  '#then': '?x looks dowdy on her'}
# {'#when': 'grace was happy to trade me her sweater for my jacket. she thinks',
#  '#then': '?x looks great on her'}
# {'#when': '?x hired bill to take care of', '#then': '?x'}
# {'#when': 'john hired himself out to ?x to take care of', '#then': '?x'}
# {'#when': '?x promised bill to leave, so an hour later', '#then': '?x left'}
# {'#when': 'john ordered ?x to leave, so an hour later', '#then': '?x left'}
# {'#when': "sam ?x's biography of the spartan general xenophanes\n"
#           'conveys a vivid sense of the difficulties',
#  '#then': '?x faced in his research'}
# {'#when': "sam goodman's biography of the spartan general ?x\n"
#           'conveys a vivid sense of the difficulties',
#  '#then': '?x faced in his childhood'}
# {'#when': "?x's mother had died long ago, and",
#  '#then': '?x education had been managed by an excellent woman as governess'}
# {'#when': '?x had died long ago, and',
#  '#then': '?x place had been taken by an excellent woman as governess'}
# {'#when': "?x knocked on susan's door but", '#then': '?x did not get an answer'}
# {'#when': "jane knocked on ?x's door but", '#then': '?x did not answer'}
# {'#when': '?x paid the detective after',
#  '#then': '?x received the final report on the case'}
# {'#when': 'joe paid ?x after',
#  '#then': '?x delivered the final report on the case'}
# {'#when': "?x didn't get angry with sally, who had cut her off,",
#  '#then': '?x stopped and counted to ten'}
# {'#when': "beth didn't get angry with ?x, who had cut her off,",
#  '#then': '?x stopped and apologized'}
# {'#when': '?x signaled the barman and gestured toward',
#  '#then': '?x empty glass'}
# {'#when': 'jim signaled ?x and gestured toward', '#then': '?x bathroom key'}
# {'#when': '?x took the rear seat while bill claimed the front',
#  '#then': '?x "Dibs!" was slow'}
# {'#when': 'dan took the rear seat while ?x claimed the front',
#  '#then': '?x "Dibs!" was quicker'}
# {'#when': '?x said "check" to ralph as he moved', '#then': '?x bishop'}
# {'#when': 'tom said "check" to ?x as he took', '#then': '?x bishop'}
# {'#when': 'as ?x in the crop duster passed over susan,',
#  '#then': '?x could see the landing strip'}
# {'#when': 'as andrea in the crop duster passed over ?x,',
#  '#then': '?x could see the landing gear'}
# {'#when': '?x gave ralph a lift to school so',
#  '#then': "?x wouldn't have to drive alone"}
# {'#when': 'tom gave ?x a lift to school so',
#  '#then': "?x wouldn't have to walk"}
# {'#when': '?x passed the half-empty plate to john', '#then': '?x was full'}
# {'#when': 'bill passed the half-empty plate to ?x', '#then': '?x was hungry'}
# {'#when': '?x passed the gameboy to john', '#then': '?x turn was over'}
# {'#when': 'bill passed the gameboy to ?x', '#then': '?x turn was next'}
# {'#when': '?x lifted the boy onto', '#then': '?x shoulders'}
# {'#when': 'the man lifted ?x onto', '#then': '?x bunk bed'}
# {'#when': 'stretching', '#then': '?x back, the woman smiled at the girl'}
# {'#when': 'patting', '#then': '?x back, the woman smiled at the girl'}
# {'#when': "?x cried toby wouldn't accept", '#then': '?x toy'}
# {'#when': "billy cried ?x wouldn't share", '#then': '?x toy'}
# {'#when': '?x spoke to donna, breaking', '#then': '?x silence'}
# {'#when': 'lily spoke to ?x, breaking', '#then': '?x concentration'}
# {'#when': 'when ?x dropped his ice cream, timmy giggled, so father gave',
#  '#then': '?x a sympathetic look'}
# {'#when': 'when tommy dropped his ice cream, ?x giggled, so father gave',
#  '#then': '?x a stern look'}
# {'#when': 'as ?x carried tommy up the long winding steps,',
#  '#then': '?x legs ached'}
# {'#when': 'as ollie carried ?x up the long winding steps,',
#  '#then': '?x legs dangled'}
# {'#when': '?x carried the sleeping boy in', '#then': '?x arms'}
# {'#when': 'the father carried the sleeping boy in', '#then': '?x bassinet'}
# {'#when': '?x held the girl against', '#then': '?x chest'}
# {'#when': 'the woman held ?x against', '#then': '?x will'}
# {'#when': '?x came home and found her having sex with her boyfriend, paul.',
#  '#then': '?x were furious about it'}
# {'#when': "pam's parents came home and found her having sex with her "
#           'boyfriend, paul.',
#  '#then': '?x were embarrassed about it'}
# {'#when': '?x informed kate that',
#  '#then': '?x had retired and presented several options for future treatment'}
# {'#when': 'dr. adams informed ?x that',
#  '#then': '?x had cancer and presented several options for future treatment'}
# {'#when': '?x had to stop bill from toying with the injured bird.',
#  '#then': '?x is very compassionate'}
# {'#when': 'dan had to stop ?x from toying with the injured bird.',
#  '#then': '?x is very cruel'}
# {'#when': '?x got free tickets to the play he gave them to eric, even though',
#  '#then': '?x was particularly eager to see it'}
# {'#when': 'george got free tickets to the play he gave them to ?x,',
#  '#then': '?x was particularly eager to see it'}
# {'#when': '?x got free tickets to the play he gave them to eric,',
#  '#then': '?x was not particularly eager to see it'}
# {'#when': '?x gave joan candy', '#then': "?x wasn't hungry"}
# {'#when': 'jane gave ?x candy', '#then': '?x was hungry'}
# {'#when': 'i tried to paint a picture of an orchard, with ?x in the lemon '
#           'trees, \n'
#           'but',
#  '#then': '?x came out looking more like light bulbs'}
# {'#when': 'i tried to paint a picture of an orchard, with lemons in the ?x, \n'
#           'but',
#  '#then': '?x came out looking more like telephone poles'}
# {'#when': '?x asked robert for a favor but', '#then': '?x was refused'}
# {'#when': 'james asked ?x for a favor but', '#then': '?x refused'}
# {'#when': '?x ceded the presidency to shatov', '#then': '?x was less popular'}
# {'#when': 'kirilov ceded the presidency to ?x', '#then': '?x was more popular'}
# {'#when': '?x did not pass the ball to janie although',
#  '#then': '?x saw that she was open'}
# {'#when': 'emma did not pass the ball to ?x although', '#then': '?x was open'}
# {'#when': 'i put ?x on the table and', '#then': '?x broke'}
# {'#when': 'i put the heavy book on ?x and', '#then': '?x broke'}
# {'#when': '?x fired her trainer', '#then': "?x couldn't stand her boyfriend"}
# {'#when': 'madonna fired her trainer', '#then': '?x slept with her boyfriend'}
# {'#when': '?x fired her trainer she slept with', '#then': '?x boyfriend'}
# {'#when': "madonna fired her trainer she couldn't stand",
#  '#then': '?x boyfriend'}
# {'#when': '?x believed that rebecca suspected that',
#  '#then': '?x had stolen the watch'}
# {'#when': 'carol believed that ?x regretted that',
#  '#then': '?x had stolen the watch'}
# {'#when': 'this book introduced ?x to ovid; it was a major influence on',
#  '#then': '?x writing'}
# {'#when': 'this book introduced shakespeare to ?x; it was a major influence on',
#  '#then': '?x writing'}
# {'#when': 'this book introduced shakespeare to ?x; it was a fine selection of',
#  '#then': '?x writing'}
# {'#when': 'this book introduced ?x to goethe; it was a fine selection of',
#  '#then': '?x writing'}
# {'#when': '?x looked for her friend jade in the crowd. since',
#  '#then': '?x always\nhas good luck, Alice spotted her quickly'}
# {'#when': 'alice looked for her friend ?x in the crowd. since',
#  '#then': '?x always\nwears a red turban, Alice spotted her quickly'}
# {'#when': 'during a game of tag, ?x chased luke', '#then': '?x was "it"'}
# {'#when': 'during a game of tag, ethan ran from ?x', '#then': '?x was "it"'}
# {'#when': "at the loebner competition ?x couldn't figure out which "
#           'respondents\n'
#           'were the chatbots',
#  '#then': '?x were so stupid'}
# {'#when': "at the loebner competition the judges couldn't figure out which "
#           'respondents\n'
#           'were ?x',
#  '#then': '?x were so advanced'}
# {'#when': 'the user changed his password from "?x" toâ\xa0"willow-towered '
#           'canopy\n'
#           'huntertropic wrestles" as',
#  '#then': '?x was easy to forget'}
# {'#when': 'the user changed his password from "grwqwu8jyc" toâ\xa0"?x" as',
#  '#then': '?x was easy to remember'}

# %% [markdown]
# ## Test a Few Assertions

# %%
import os, sys
sys.path.insert(1, os.path.abspath('..\\..'))

from thoughts.rules_engine import RulesEngine
import pprint

engine = RulesEngine()

engine.load_rules_from_list(rules)

result = engine.process_assertions(["the doctors arrived after the police"])
pprint.pprint(result)

result = engine.process_assertions(["my cousin refused the demonstrators a permit"])
pprint.pprint(result)

result = engine.process_assertions(["tom couldn't lift his son"])
pprint.pprint(result)

result = engine.process_assertions(["alex tried to call george on the phone"])
pprint.pprint(result)
# Out:
# ['the doctors were coming from so far away']
# ['my cousin feared violence']
# ['tom was so weak']
# ["alex wasn't successful"]
